# %%
p1 = 214/700

# %%
p1
# Out:
# 0.3057142857142857

# %%
2 * p1 * (1-p1)
# Out:
# 0.4245061224489796

# %%
import pandas as pd
import numpy as np
from sklearn import *
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
df = pd.read_csv("/data/credit-default.csv")

# %%
label = "default"
X = df.drop(columns=[label]) # features
y = preprocessing.LabelEncoder().fit_transform(df[label])

X_dummy = pd.get_dummies(X, drop_first=True) # OneHot Encoding



#X: features, y: label
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_dummy,
                                         y, test_size = 0.3, random_state = 1546)


pipe = pipeline.Pipeline([
    ("poly", preprocessing.PolynomialFeatures(degree=1, include_bias=False)),
    ("scaler", preprocessing.StandardScaler()),
    ("est", linear_model.LogisticRegression())
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

print("Training accuracy", metrics.accuracy_score(y_train, y_train_pred))
print("Test accuracy", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Training accuracy 0.8114285714285714
# Test accuracy 0.7533333333333333

# %%
est.coef_[0].shape
# Out:
# (48,)

# %%
est = pipe.steps[-1][-1]
summary = pd.DataFrame({"feature": X_dummy.columns, "coefficient": est.coef_[0]})
summary["coefficient_abs"] = np.abs(summary.coefficient)
summary.sort_values("coefficient_abs", ascending = False)
# Out:
#                                   feature  coefficient  coefficient_abs
# 13                  credit_history_repaid     0.576190         0.576190
# 14                      purpose_car (new)     0.490885         0.490885
# 33            personal_status_single male    -0.456825         0.456825
# 9                checking_balance_unknown    -0.450606         0.450606
# 42                           housing_rent     0.431754         0.431754
# 12  credit_history_fully repaid this bank     0.424698         0.424698
# 34                other_debtors_guarantor    -0.423075         0.423075
# 11            credit_history_fully repaid     0.383383         0.383383
# 44                     foreign_worker_yes     0.376042         0.376042
# 1                                  amount     0.374847         0.374847
# 39                  installment_plan_none    -0.357334         0.357334
# 0                    months_loan_duration     0.354953         0.354953
# 25              savings_balance_> 1000 DM    -0.351473         0.351473
# 15                     purpose_car (used)    -0.342915         0.342915
# 28            employment_length_4 - 7 yrs    -0.331163         0.331163
# 2                        installment_rate     0.314942         0.314942
# 31                 personal_status_female    -0.301683         0.301683
# 22                     purpose_retraining    -0.275813         0.275813
# 38                  property_unknown/none     0.254856         0.254856
# 7                 checking_balance_< 0 DM     0.231891         0.231891
# 35                     other_debtors_none    -0.224281         0.224281
# 41                            housing_own     0.216066         0.216066
# 26                savings_balance_unknown    -0.213991         0.213991
# 37                   property_real estate    -0.197602         0.197602
# 17                      purpose_education     0.196253         0.196253
# 45                   job_skilled employee    -0.188713         0.188713
# 10                 credit_history_delayed     0.184680         0.184680
# 5                        existing_credits     0.178324         0.178324
# 29              employment_length_> 7 yrs    -0.175174         0.175174
# 8               checking_balance_> 200 DM    -0.173919         0.173919
# 24               savings_balance_< 100 DM     0.169851         0.169851
# 43                          telephone_yes    -0.162736         0.162736
# 21                        purpose_repairs     0.157247         0.157247
# 16            purpose_domestic appliances     0.156726         0.156726
# 23          savings_balance_501 - 1000 DM    -0.126362         0.126362
# 46            job_unemployed non-resident    -0.108538         0.108538
# 32           personal_status_married male    -0.108123         0.108123
# 27            employment_length_1 - 4 yrs    -0.100601         0.100601
# 40                installment_plan_stores    -0.100326         0.100326
# 3                       residence_history    -0.097561         0.097561
# 36                         property_other    -0.082795         0.082795
# 20                       purpose_radio/tv     0.066810         0.066810
# 47                 job_unskilled resident    -0.056958         0.056958
# 18                      purpose_furniture     0.052065         0.052065
# 19                         purpose_others    -0.042948         0.042948
# 4                                     age    -0.023912         0.023912
# 30           employment_length_unemployed    -0.021651         0.021651
# 6                              dependents    -0.002412         0.002412

# %%
label = "default"
X = df.drop(columns=[label]) # features
y = preprocessing.LabelEncoder().fit_transform(df[label])

X_dummy = pd.get_dummies(X, drop_first=True) # OneHot Encoding



#X: features, y: label
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_dummy,
                                         y, test_size = 0.3, random_state = 1546)


pipe = pipeline.Pipeline([
    #("poly", preprocessing.PolynomialFeatures(degree=1, include_bias=False)),
    #("scaler", preprocessing.StandardScaler()),
    ("est", tree.DecisionTreeClassifier(max_depth=3, min_samples_leaf=10))
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

print("Training accuracy", metrics.accuracy_score(y_train, y_train_pred))
print("Test accuracy", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Training accuracy 0.74
# Test accuracy 0.67

# %%
est = pipe.steps[-1][-1]

# %%
from sklearn.tree import export_graphviz
export_graphviz(est, out_file = "tree.dot", feature_names = X_dummy.columns, filled=True)
# !dot -Tpng tree.dot -o tree.png

# %%
est = pipe.steps[-1][-1]
summary = pd.DataFrame({"feature": X_dummy.columns
                        , "importance": est.feature_importances_})
summary.sort_values("importance", ascending = False)
# Out:
#                                   feature  importance
# 9                checking_balance_unknown    0.232673
# 1                                  amount    0.115000
# 14                      purpose_car (new)    0.105092
# 0                    months_loan_duration    0.064791
# 24               savings_balance_< 100 DM    0.054598
# 4                                     age    0.050266
# 38                  property_unknown/none    0.042885
# 26                savings_balance_unknown    0.040003
# 2                        installment_rate    0.034888
# 23          savings_balance_501 - 1000 DM    0.034359
# 45                   job_skilled employee    0.026040
# 7                 checking_balance_< 0 DM    0.025958
# 41                            housing_own    0.022237
# 42                           housing_rent    0.018135
# 13                  credit_history_repaid    0.017923
# 27            employment_length_1 - 4 yrs    0.016993
# 5                        existing_credits    0.016363
# 31                 personal_status_female    0.014184
# 37                   property_real estate    0.013828
# 6                              dependents    0.013256
# 15                     purpose_car (used)    0.013101
# 29              employment_length_> 7 yrs    0.009113
# 3                       residence_history    0.005742
# 35                     other_debtors_none    0.004956
# 10                 credit_history_delayed    0.002761
# 28            employment_length_4 - 7 yrs    0.002591
# 32           personal_status_married male    0.002260
# 11            credit_history_fully repaid    0.000000
# 36                         property_other    0.000000
# 43                          telephone_yes    0.000000
# 44                     foreign_worker_yes    0.000000
# 40                installment_plan_stores    0.000000
# 8               checking_balance_> 200 DM    0.000000
# 39                  installment_plan_none    0.000000
# 12  credit_history_fully repaid this bank    0.000000
# 46            job_unemployed non-resident    0.000000
# 17                      purpose_education    0.000000
# 34                other_debtors_guarantor    0.000000
# 33            personal_status_single male    0.000000
# 18                      purpose_furniture    0.000000
# 30           employment_length_unemployed    0.000000
# 25              savings_balance_> 1000 DM    0.000000
# 16            purpose_domestic appliances    0.000000
# 22                     purpose_retraining    0.000000
# 21                        purpose_repairs    0.000000
# 20                       purpose_radio/tv    0.000000
# 19                         purpose_others    0.000000
# 47                 job_unskilled resident    0.000000

# %%
label = "default"
X = df.drop(columns=[label]) # features
y = preprocessing.LabelEncoder().fit_transform(df[label])

X_dummy = pd.get_dummies(X, drop_first=True) # OneHot Encoding



#X: features, y: label
X_train, X_test, y_train, y_test = model_selection.train_test_split(X_dummy,
                                         y, test_size = 0.3, random_state = 1546)


pipe = pipeline.Pipeline([
    #("poly", preprocessing.PolynomialFeatures(degree=1, include_bias=False)),
    #("scaler", preprocessing.StandardScaler()),
    ("est", ensemble.RandomForestClassifier(max_depth=3, min_samples_leaf=10))
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

print("Training accuracy", metrics.accuracy_score(y_train, y_train_pred))
print("Test accuracy", metrics.accuracy_score(y_test, y_test_pred))
# Out:
# Training accuracy 0.7071428571428572
# Test accuracy 0.7333333333333333

# %%
est = pipe.steps[-1][-1]
summary = pd.DataFrame({"feature": X_dummy.columns
                        , "importance": est.feature_importances_})
summary.sort_values("importance", ascending = False)
# Out:
#                                   feature  importance
# 9                checking_balance_unknown    0.232673
# 1                                  amount    0.115000
# 14                      purpose_car (new)    0.105092
# 0                    months_loan_duration    0.064791
# 24               savings_balance_< 100 DM    0.054598
# 4                                     age    0.050266
# 38                  property_unknown/none    0.042885
# 26                savings_balance_unknown    0.040003
# 2                        installment_rate    0.034888
# 23          savings_balance_501 - 1000 DM    0.034359
# 45                   job_skilled employee    0.026040
# 7                 checking_balance_< 0 DM    0.025958
# 41                            housing_own    0.022237
# 42                           housing_rent    0.018135
# 13                  credit_history_repaid    0.017923
# 27            employment_length_1 - 4 yrs    0.016993
# 5                        existing_credits    0.016363
# 31                 personal_status_female    0.014184
# 37                   property_real estate    0.013828
# 6                              dependents    0.013256
# 15                     purpose_car (used)    0.013101
# 29              employment_length_> 7 yrs    0.009113
# 3                       residence_history    0.005742
# 35                     other_debtors_none    0.004956
# 10                 credit_history_delayed    0.002761
# 28            employment_length_4 - 7 yrs    0.002591
# 32           personal_status_married male    0.002260
# 11            credit_history_fully repaid    0.000000
# 36                         property_other    0.000000
# 43                          telephone_yes    0.000000
# 44                     foreign_worker_yes    0.000000
# 40                installment_plan_stores    0.000000
# 8               checking_balance_> 200 DM    0.000000
# 39                  installment_plan_none    0.000000
# 12  credit_history_fully repaid this bank    0.000000
# 46            job_unemployed non-resident    0.000000
# 17                      purpose_education    0.000000
# 34                other_debtors_guarantor    0.000000
# 33            personal_status_single male    0.000000
# 18                      purpose_furniture    0.000000
# 30           employment_length_unemployed    0.000000
# 25              savings_balance_> 1000 DM    0.000000
# 16            purpose_domestic appliances    0.000000
# 22                     purpose_retraining    0.000000
# 21                        purpose_repairs    0.000000
# 20                       purpose_radio/tv    0.000000
# 19                         purpose_others    0.000000
# 47                 job_unskilled resident    0.000000

# %%
est.estimators_
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1173817879, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1894583486, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=955979671, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1797877065, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1393638598, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1590971070, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1751626900, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=162392750, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1343361324, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#              max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=10, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, presort=False,
#              random_state=1908096128, splitter='best')]
