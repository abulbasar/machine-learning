# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.linspace(-7, 7, 1000)

# %%
a = 1 / (1 + np.exp(-z))

# %%
plt.plot(z, a)

# %%
y = np.where(z >= 0, 1, 0)

# %%
l = y * a + (1-y) * (1 - a)
plt.plot(z, l)
