# %%
import pandas as pd
import numpy as np
from sklearn import *
import matplotlib.pyplot as plt
import skimage
from skimage  import io, color

from mlxtend.plotting import plot_decision_regions

# %matplotlib inline

# %%
img_origin = io.imread("/Users/abulbasar/Downloads/pic.jpeg")
img = color.rgb2gray(img_origin)
img.shape
# Out:
# (183, 275)

# %%
plt.imshow(img_origin)

# %%
plt.imshow(img, cmap="Greys")

# %%
a = img.reshape(-1, 1)
a.shape
# Out:
# (50325, 1)

# %%
kmeans = cluster.MiniBatchKMeans(n_clusters=5)
y = kmeans.fit_predict(preprocessing.StandardScaler().fit_transform(a))
plt.imshow(y.reshape(img.shape), cmap="Greys")
# Out:
# /Users/abulbasar/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
a = img_origin.reshape(-1, 3)
a.shape, img_origin.shape
# Out:
# ((50325, 3), (183, 275, 3))

# %%
kmeans = cluster.MiniBatchKMeans(n_clusters=5)
y = kmeans.fit_predict(preprocessing.StandardScaler().fit_transform(a.astype(np.float32)))
plt.imshow(y.reshape(img.shape[:2]), cmap="Greys")

# %%
183 * 275
# Out:
# 50325
