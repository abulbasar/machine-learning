# %%
import pandas as pd

# %%
df = pd.read_csv("/data/insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Common tasks with dataframe
#
#
# 1. refer portion using row index or column index or columns names
# 2. filter
# 3. Group
# 4. sorting
# 5. merging / joining

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df[["region", "charges"]].head()
# Out:
#       region      charges
# 0  southwest  16884.92400
# 1  southeast   1725.55230
# 2  southeast   4449.46200
# 3  northwest  21984.47061
# 4  northwest   3866.85520

# %%
type(df["charges"])
# Out:
# pandas.core.series.Series

# %%
df["charges"]
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
# 6        8240.58960
# 7        7281.50560
# 8        6406.41070
# 9       28923.13692
# 10       2721.32080
# 11      27808.72510
# 12       1826.84300
# 13      11090.71780
# 14      39611.75770
# 15       1837.23700
# 16      10797.33620
# 17       2395.17155
# 18      10602.38500
# 19      36837.46700
# 20      13228.84695
# 21       4149.73600
# 22       1137.01100
# 23      37701.87680
# 24       6203.90175
# 25      14001.13380
# 26      14451.83515
# 27      12268.63225
# 28       2775.19215
# 29      38711.00000
#            ...
# 1308    33900.65300
# 1309     6875.96100
# 1310     6940.90985
# 1311     4571.41305
# 1312     4536.25900
# 1313    36397.57600
# 1314    18765.87545
# 1315    11272.33139
# 1316     1731.67700
# 1317     1163.46270
# 1318    19496.71917
# 1319     7201.70085
# 1320     5425.02335
# 1321    28101.33305
# ...

# %%
df.iloc[4:9, :]
# Out:
#    age     sex    bmi  children smoker     region    charges
# 4   32    male  28.88         0     no  northwest  3866.8552
# 5   31  female  25.74         0     no  southeast  3756.6216
# 6   46  female  33.44         1     no  southeast  8240.5896
# 7   37  female  27.74         3     no  northwest  7281.5056
# 8   37    male  29.83         2     no  northeast  6406.4107

# %%
df.iloc[4:9, [2, 6]]
# Out:
#      bmi    charges
# 4  28.88  3866.8552
# 5  25.74  3756.6216
# 6  33.44  8240.5896
# 7  27.74  7281.5056
# 8  29.83  6406.4107

# %%
df.iloc[4:9, [2, -1]]
# Out:
#      bmi    charges
# 4  28.88  3866.8552
# 5  25.74  3756.6216
# 6  33.44  8240.5896
# 7  27.74  7281.5056
# 8  29.83  6406.4107

# %%
df.loc[4:9, ["bmi", "charges"]]
# Out:
#      bmi      charges
# 4  28.88   3866.85520
# 5  25.74   3756.62160
# 6  33.44   8240.58960
# 7  27.74   7281.50560
# 8  29.83   6406.41070
# 9  25.84  28923.13692

# %%
df[df.sex == "female"]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 9      60  female  25.840         0     no  northwest  28923.13692
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 13     56  female  39.820         0     no  southeast  11090.71780
# 16     52  female  30.780         1     no  northeast  10797.33620
# 20     60  female  36.005         0     no  northeast  13228.84695
# 21     30  female  32.400         1     no  southwest   4149.73600
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 25     59  female  27.720         3     no  southeast  14001.13380
# 26     63  female  23.085         0     no  northeast  14451.83515
# ...

# %%
df.query("sex == 'female'")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 9      60  female  25.840         0     no  northwest  28923.13692
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 13     56  female  39.820         0     no  southeast  11090.71780
# 16     52  female  30.780         1     no  northeast  10797.33620
# 20     60  female  36.005         0     no  northeast  13228.84695
# 21     30  female  32.400         1     no  southwest   4149.73600
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 25     59  female  27.720         3     no  southeast  14001.13380
# 26     63  female  23.085         0     no  northeast  14451.83515
# ...

# %%
import numpy as np

# %%
(df.sex == "female") | (df.smoker == "yes")
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5        True
# 6        True
# 7        True
# 8       False
# 9        True
# 10      False
# 11       True
# 12      False
# 13       True
# 14       True
# 15      False
# 16       True
# 17      False
# 18      False
# 19       True
# 20       True
# 21       True
# 22      False
# 23       True
# 24      False
# 25       True
# 26       True
# 27       True
# 28      False
# 29       True
#         ...
# 1308     True
# 1309    False
# 1310    False
# 1311     True
# 1312    False
# 1313     True
# 1314     True
# 1315    False
# 1316     True
# 1317    False
# 1318    False
# 1319     True
# 1320    False
# 1321     True
# 1322    False
# 1323     True
# 1324    False
# 1325    False
# 1326     True
# 1327    False
# 1328     True
# 1329    False
# 1330     True
# 1331     True
# 1332     True
# 1333    False
# 1334     True
# 1335     True
# 1336     True
# 1337     True
# ...

# %%
df[(df.sex == "female") & (df.smoker == "yes")]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# 64     20  female  22.420         0    yes  northwest  14711.74380
# 70     27  female  24.750         0    yes  southeast  16577.77950
# 84     37  female  34.800         2    yes  southwest  39836.51900
# 86     57  female  31.160         0    yes  northwest  43578.93940
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 103    61  female  29.920         3    yes  southeast  30942.19180
# 117    29  female  27.940         1    yes  southeast  19107.77960
# 126    19  female  28.300         0    yes  southwest  17081.08000
# 128    32  female  17.765         2    yes  northwest  32734.18630
# ...

# %%
df.query("sex == 'female' and smoker == 'yes'")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# 64     20  female  22.420         0    yes  northwest  14711.74380
# 70     27  female  24.750         0    yes  southeast  16577.77950
# 84     37  female  34.800         2    yes  southwest  39836.51900
# 86     57  female  31.160         0    yes  northwest  43578.93940
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 103    61  female  29.920         3    yes  southeast  30942.19180
# 117    29  female  27.940         1    yes  southeast  19107.77960
# 126    19  female  28.300         0    yes  southwest  17081.08000
# 128    32  female  17.765         2    yes  northwest  32734.18630
# ...

# %%
df.groupby("sex").charges.mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
df.groupby("sex").charges.agg([np.mean, np.median])
# Out:
#                 mean      median
# sex
# female  12569.578844  9412.96250
# male    13956.751178  9369.61575

# %%
df.groupby("sex").apply(lambda rows: (np.mean(rows.charges), np.mean(rows.bmi)))
# Out:
# sex
# female     (12569.57884383534, 30.377749244713023)
# male      (13956.751177721886, 30.943128698224832)
# dtype: object

# %%
df.groupby("sex").apply(lambda rows: {"charges_mean": np.mean(rows.charges), 
                                      "bmi_median": np.mean(rows.bmi)})
# Out:
# sex
# female    {'charges_mean': 12569.57884383534, 'bmi_media...
# male      {'charges_mean': 13956.751177721886, 'bmi_medi...
# dtype: object

# %%
df.sort_values("age", ascending=False)
# Out:
#       age     sex     bmi  children smoker     region       charges
# 335    64    male  34.500         0     no  southwest  13822.803000
# 603    64  female  39.050         3     no  southeast  16085.127500
# 752    64    male  37.905         0     no  northwest  14210.535950
# 1265   64    male  23.760         0    yes  southeast  26926.514400
# 534    64    male  40.480         0     no  southeast  13831.115200
# 328    64  female  33.800         1    yes  southwest  47928.030000
# 768    64  female  39.700         0     no  southwest  14319.031000
# 1241   64    male  36.960         2    yes  southeast  49577.662400
# 62     64    male  24.700         1     no  northwest  30166.618170
# 801    64  female  35.970         0     no  southeast  14313.846300
# 825    64  female  31.825         2     no  northeast  16069.084750
# 378    64  female  30.115         3     no  northwest  16455.707850
# 398    64    male  25.600         2     no  southwest  14988.432000
# ...

# %%
df.sort_values(["age", "bmi"], ascending=False)
# Out:
#       age     sex     bmi  children smoker     region       charges
# 534    64    male  40.480         0     no  southeast  13831.115200
# 768    64  female  39.700         0     no  southwest  14319.031000
# 199    64  female  39.330         0     no  northeast  14901.516700
# 418    64    male  39.160         1     no  southeast  14418.280400
# 603    64  female  39.050         3     no  southeast  16085.127500
# 635    64    male  38.190         0     no  northeast  14410.932100
# 752    64    male  37.905         0     no  northwest  14210.535950
# 1241   64    male  36.960         2    yes  southeast  49577.662400
# 801    64  female  35.970         0     no  southeast  14313.846300
# 335    64    male  34.500         0     no  southwest  13822.803000
# 420    64    male  33.880         0    yes  southeast  46889.261200
# 328    64  female  33.800         1    yes  southwest  47928.030000
# 402    64  female  32.965         0     no  northwest  14692.669350
# ...

# %%
df.sort_values(["age", "bmi"], ascending=[False, True])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 664    64  female  22.990         0    yes  southeast  27037.91410
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 62     64    male  24.700         1     no  northwest  30166.61817
# 398    64    male  25.600         2     no  southwest  14988.43200
# 1051   64    male  26.410         0     no  northeast  14394.55790
# 890    64  female  26.885         0    yes  northwest  29330.98315
# 378    64  female  30.115         3     no  northwest  16455.70785
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 825    64  female  31.825         2     no  northeast  16069.08475
# 402    64  female  32.965         0     no  northwest  14692.66935
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 335    64    male  34.500         0     no  southwest  13822.80300
# ...

# %%
df.columns[[0, 2]]
# Out:
# Index(['age', 'bmi'], dtype='object')

# %%
df.sort_values(list(df.columns[[0, 2]]), ascending=[False, True])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 664    64  female  22.990         0    yes  southeast  27037.91410
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 62     64    male  24.700         1     no  northwest  30166.61817
# 398    64    male  25.600         2     no  southwest  14988.43200
# 1051   64    male  26.410         0     no  northeast  14394.55790
# 890    64  female  26.885         0    yes  northwest  29330.98315
# 378    64  female  30.115         3     no  northwest  16455.70785
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 825    64  female  31.825         2     no  northeast  16069.08475
# 402    64  female  32.965         0     no  northwest  14692.66935
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 335    64    male  34.500         0     no  southwest  13822.80300
# ...

# %%
df.groupby("sex").age.agg([np.mean, len]).reset_index()
# Out:
#       sex       mean  len
# 0  female  39.503021  662
# 1    male  38.917160  676
