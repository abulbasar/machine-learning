# %%
import pandas as pd

# %%
df = pd.read_csv("/data/insurance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # List of common operations
#
# 1. number of records
# 2. Number of columns
# 3. column types
# 4. Slice the data frame - by indices, or by name
# 5. filter
# 6. sort
# 7. group
# 8. merge
# 9. pivot
# 10. null handle
# 11. mutate
# 12. show head/tail
# 13. sample

# %%
len(df)
# Out:
# 1338

# %%
len(df.columns)
# Out:
# 7

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.shape
# Out:
# (1338, 7)

# %%
dict(df.dtypes)
# Out:
# {'age': dtype('int64'),
#  'gender': dtype('O'),
#  'bmi': dtype('float64'),
#  'children': dtype('int64'),
#  'smoker': dtype('O'),
#  'region': dtype('O'),
#  'charges': dtype('float64')}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.head(10)
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.sample(10)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1237   58  female  28.215         0     no  northwest  12224.35085
# 1093   22  female  30.400         0    yes  northwest  33907.54800
# 120    44    male  37.100         2     no  southwest   7740.33700
# 764    45  female  25.175         2     no  northeast   9095.06825
# 746    34    male  27.000         2     no  southwest  11737.84884
# 1010   48  female  22.800         0     no  southwest   8269.04400
# 872    42    male  24.860         0     no  southeast   5966.88740
# 734    59  female  32.100         3     no  southwest  14007.22200
# 489    53    male  31.160         1     no  northwest  10461.97940
# 221    53  female  33.250         0     no  northeast  10564.88450

# %%
df.iloc[10:16, :]
# Out:
#     age  gender    bmi  children smoker     region     charges
# 10   25    male  26.22         0     no  northeast   2721.3208
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 12   23    male  34.40         0     no  southwest   1826.8430
# 13   56  female  39.82         0     no  southeast  11090.7178
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 15   19    male  24.60         1     no  southwest   1837.2370

# %%
df.iloc[10:16, :3]
# Out:
#     age  gender    bmi
# 10   25    male  26.22
# 11   62  female  26.29
# 12   23    male  34.40
# 13   56  female  39.82
# 14   27    male  42.13
# 15   19    male  24.60

# %%
df[["age", "gender", "bmi"]]
# Out:
#       age  gender     bmi
# 0      19  female  27.900
# 1      18    male  33.770
# 2      28    male  33.000
# 3      33    male  22.705
# 4      32    male  28.880
# 5      31  female  25.740
# 6      46  female  33.440
# 7      37  female  27.740
# 8      37    male  29.830
# 9      60  female  25.840
# 10     25    male  26.220
# 11     62  female  26.290
# 12     23    male  34.400
# 13     56  female  39.820
# 14     27    male  42.130
# 15     19    male  24.600
# 16     52  female  30.780
# 17     23    male  23.845
# 18     56    male  40.300
# 19     30    male  35.300
# 20     60  female  36.005
# 21     30  female  32.400
# 22     18    male  34.100
# 23     34  female  31.920
# 24     37    male  28.025
# 25     59  female  27.720
# 26     63  female  23.085
# 27     55  female  32.775
# 28     23    male  17.385
# 29     31    male  36.300
# ...   ...     ...     ...
# 1308   25  female  30.200
# 1309   41    male  32.200
# 1310   42    male  26.315
# ...

# %%
type(df["age"]), type(df[["age"]])
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df[df.gender == "male"]
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 2      28   male  33.000         3     no  southeast   4449.46200
# 3      33   male  22.705         0     no  northwest  21984.47061
# 4      32   male  28.880         0     no  northwest   3866.85520
# 8      37   male  29.830         2     no  northeast   6406.41070
# 10     25   male  26.220         0     no  northeast   2721.32080
# 12     23   male  34.400         0     no  southwest   1826.84300
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 15     19   male  24.600         1     no  southwest   1837.23700
# 17     23   male  23.845         0     no  northeast   2395.17155
# 18     56   male  40.300         0     no  southwest  10602.38500
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 22     18   male  34.100         0     no  southeast   1137.01100
# ...

# %%
df.gender == "male"
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10       True
# 11      False
# 12       True
# 13      False
# 14       True
# 15       True
# 16      False
# 17       True
# 18       True
# 19       True
# 20      False
# 21      False
# 22       True
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28       True
# 29       True
#         ...
# 1308    False
# 1309     True
# 1310     True
# 1311    False
# 1312     True
# 1313    False
# 1314    False
# 1315     True
# 1316    False
# 1317     True
# 1318     True
# 1319    False
# 1320     True
# 1321     True
# 1322     True
# 1323    False
# 1324     True
# 1325     True
# 1326    False
# 1327     True
# 1328    False
# 1329     True
# 1330    False
# 1331    False
# 1332    False
# 1333     True
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# ...

# %%
df[(df.gender == "male") & (df.smoker == "yes")]
# Out:
#       age gender     bmi  children smoker     region      charges
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 29     31   male  36.300         2    yes  southwest  38711.00000
# 30     22   male  35.600         0    yes  southwest  35585.57600
# 34     28   male  36.400         1    yes  southwest  51194.55914
# 38     35   male  36.670         1    yes  northeast  39774.27630
# 39     60   male  39.900         0    yes  southwest  48173.36100
# 49     36   male  35.200         1    yes  southeast  38709.17600
# 52     48   male  28.000         1    yes  southwest  23568.27200
# 53     36   male  34.430         0    yes  southeast  37742.57570
# 55     58   male  36.955         2    yes  northwest  47496.49445
# 57     18   male  31.680         2    yes  southeast  34303.16720
# 69     28   male  23.980         3    yes  southeast  17663.14420
# ...

# %%
df.query("gender == 'male' and smoker == 'yes'")
# Out:
#       age gender     bmi  children smoker     region      charges
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 29     31   male  36.300         2    yes  southwest  38711.00000
# 30     22   male  35.600         0    yes  southwest  35585.57600
# 34     28   male  36.400         1    yes  southwest  51194.55914
# 38     35   male  36.670         1    yes  northeast  39774.27630
# 39     60   male  39.900         0    yes  southwest  48173.36100
# 49     36   male  35.200         1    yes  southeast  38709.17600
# 52     48   male  28.000         1    yes  southwest  23568.27200
# 53     36   male  34.430         0    yes  southeast  37742.57570
# 55     58   male  36.955         2    yes  northwest  47496.49445
# 57     18   male  31.680         2    yes  southeast  34303.16720
# 69     28   male  23.980         3    yes  southeast  17663.14420
# ...

# %%
df[["age", "gender", "bmi"]].iloc[:10]
# Out:
#    age  gender     bmi
# 0   19  female  27.900
# 1   18    male  33.770
# 2   28    male  33.000
# 3   33    male  22.705
# 4   32    male  28.880
# 5   31  female  25.740
# 6   46  female  33.440
# 7   37  female  27.740
# 8   37    male  29.830
# 9   60  female  25.840

# %%
df.sort_values(["age", "bmi"], ascending = [True, False])
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 442    18    male  43.010         0     no  southeast   1149.39590
# 803    18  female  42.240         0    yes  southeast  38792.68560
# 781    18    male  41.140         0     no  southeast   1146.79660
# 728    18  female  40.280         0     no  northeast   2217.60120
# 898    18  female  40.260         0     no  southeast   1634.57340
# 942    18  female  40.185         0     no  northeast   2217.46915
# 1248   18  female  39.820         0     no  southeast   1633.96180
# 600    18  female  39.160         0     no  southeast   1633.04440
# 1215   18    male  39.140         0     no  northeast  12890.05765
# 46     18  female  38.665         2     no  northeast   3393.35635
# 181    18  female  38.280         0     no  southeast   1631.82120
# 354    18  female  38.280         0     no  southeast  14133.03775
# ...

# %%
df.groupby("gender").age.mean()
# Out:
# gender
# female    39.503021
# male      38.917160
# Name: age, dtype: float64

# %%
import numpy as np

# %%
a = [7, 5, 8, 10, 23]
np.mean(a), np.median(a)
# Out:
# (10.6, 8.0)

# %%
a = [7, 5, 8, 10, 23, 1000]
np.mean(a),  np.median(a)
# Out:
# (175.5, 9.0)

# %%
df.groupby("gender").age.agg(["mean", "median", "count"])
# Out:
#              mean  median  count
# gender
# female  39.503021      40    662
# male    38.917160      39    676

# %%
df.groupby("gender").agg({"age": "mean", "bmi": "mean"})
# Out:
#               age        bmi
# gender
# female  39.503021  30.377749
# male    38.917160  30.943129

# %%
df.groupby("gender").agg({"age": ["mean", "median"], "bmi": ["mean", "median"]})
# Out:
#               age               bmi
#              mean median       mean   median
# gender
# female  39.503021     40  30.377749  30.1075
# male    38.917160     39  30.943129  30.6875

# %%
df.groupby(["region", "gender"]).agg({"age": ["mean", "median"], "bmi": ["mean", "median"]})
# Out:
#                         age               bmi
#                        mean median       mean   median
# region    gender
# northeast female  39.639752     40  29.324317  29.1650
#           male    38.901840     39  29.024540  28.8800
# northwest female  39.591463     40  29.277957  28.9275
#           male    38.795031     38  29.120155  28.8800
# southeast female  39.108571     39  32.671257  32.2300
#           male    38.783069     39  33.990000  34.1000
# southwest female  39.703704     40  30.060494  29.7500
#           male    39.208589     39  31.129448  30.8000

# %%
df.pivot_table("charges", "region", "gender")
# Out:
# gender           female          male
# region
# northeast  12953.203151  13854.005374
# northwest  12479.870397  12354.119575
# southeast  13499.669243  15879.617173
# southwest  11274.411264  13412.883576

# %%
df.pivot_table("charges", "region", "gender",aggfunc="mean")
# Out:
# gender           female          male
# region
# northeast  12953.203151  13854.005374
# northwest  12479.870397  12354.119575
# southeast  13499.669243  15879.617173
# southwest  11274.411264  13412.883576

# %%
df.pivot_table("charges", "region", "gender",aggfunc="median")
# Out:
# gender         female        male
# region
# northeast  10197.7722  9957.72160
# northwest   9614.0729  8413.46305
# southeast   8582.3023  9504.31030
# southwest   8530.8370  9391.34600

# %%
df.pivot_table("charges", "region", "gender",aggfunc=["median", "mean"])
# Out:
#                median                      mean
# gender         female        male        female          male
# region
# northeast  10197.7722  9957.72160  12953.203151  13854.005374
# northwest   9614.0729  8413.46305  12479.870397  12354.119575
# southeast   8582.3023  9504.31030  13499.669243  15879.617173
# southwest   8530.8370  9391.34600  11274.411264  13412.883576

# %%
df["charges_log"] = np.log(df.charges)
df
# Out:
#       age  gender     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
df["risky"] = df.apply(lambda row: "yes" 
                               if row.gender == "male" and row.bmi>40 else "no", axis = 1)

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# 6      46  female  33.440         1     no  southeast   8240.58960
# 7      37  female  27.740         3     no  northwest   7281.50560
# 8      37    male  29.830         2     no  northeast   6406.41070
# 9      60  female  25.840         0     no  northwest  28923.13692
# 10     25    male  26.220         0     no  northeast   2721.32080
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 12     23    male  34.400         0     no  southwest   1826.84300
# ...
