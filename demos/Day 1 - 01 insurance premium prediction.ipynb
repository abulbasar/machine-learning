# %%
import sys

# %%
sys.version
# Out:
# '3.6.5 |Anaconda, Inc.| (default, Mar 29 2018, 13:14:23) \n[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
df = pd.read_csv("/data/insurance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
# !head /data/insurance.csv
# Out:
# age,gender,bmi,children,smoker,region,charges
# 19,female,27.9,0,yes,southwest,16884.924
# 18,male,33.77,1,no,southeast,1725.5523
# 28,male,33,3,no,southeast,4449.462
# 33,male,22.705,0,no,northwest,21984.47061
# 32,male,28.88,0,no,northwest,3866.8552
# 31,female,25.74,0,no,southeast,3756.6216
# 46,female,33.44,1,no,southeast,8240.5896
# 37,female,27.74,3,no,northwest,7281.5056
# 37,male,29.83,2,no,northeast,6406.4107

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_dummy = pd.get_dummies(df, drop_first=True)
df_dummy
# Out:
#       age     bmi  children      charges  gender_male  smoker_yes  \
# 0      19  27.900         0  16884.92400            0           1
# 1      18  33.770         1   1725.55230            1           0
# 2      28  33.000         3   4449.46200            1           0
# 3      33  22.705         0  21984.47061            1           0
# 4      32  28.880         0   3866.85520            1           0
# 5      31  25.740         0   3756.62160            0           0
# 6      46  33.440         1   8240.58960            0           0
# 7      37  27.740         3   7281.50560            0           0
# 8      37  29.830         2   6406.41070            1           0
# 9      60  25.840         0  28923.13692            0           0
# 10     25  26.220         0   2721.32080            1           0
# 11     62  26.290         0  27808.72510            0           1
# 12     23  34.400         0   1826.84300            1           0
# 13     56  39.820         0  11090.71780            0           0
# 14     27  42.130         0  39611.75770            1           1
# 15     19  24.600         1   1837.23700            1           0
# 16     52  30.780         1  10797.33620            0           0
# 17     23  23.845         0   2395.17155            1           0
# 18     56  40.300         0  10602.38500            1           0
# 19     30  35.300         0  36837.46700            1           1
# 20     60  36.005         0  13228.84695            0           0
# 21     30  32.400         1   4149.73600            0           0
# 22     18  34.100         0   1137.01100            1           0
# 23     34  31.920         1  37701.87680            0           1
# 24     37  28.025         2   6203.90175            1           0
# 25     59  27.720         3  14001.13380            0           0
# 26     63  23.085         0  14451.83515            0           0
# 27     55  32.775         2  12268.63225            0           0
# 28     23  17.385         1   2775.19215            1           0
# 29     31  36.300         2  38711.00000            1           1
# ...   ...     ...       ...          ...          ...         ...
# 1308   25  30.200         0  33900.65300            0           1
# 1309   41  32.200         2   6875.96100            1           0
# 1310   42  26.315         1   6940.90985            1           0
# 1311   33  26.695         0   4571.41305            0           0
# 1312   34  42.900         1   4536.25900            1           0
# 1313   19  34.700         2  36397.57600            0           1
# 1314   30  23.655         3  18765.87545            0           1
# 1315   18  28.310         1  11272.33139            1           0
# 1316   19  20.600         0   1731.67700            0           0
# 1317   18  53.130         0   1163.46270            1           0
# 1318   35  39.710         4  19496.71917            1           0
# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, 
                                    test_size= 0.3, random_state = 1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((936, 8), (402, 8), (936,), (402,))

# %%
936 / (936 + 402)
# Out:
# 0.6995515695067265

# %%
import numpy as np

# %%
np.random.seed(123)
np.random.randn(5)
# Out:
# array([-1.0856306 ,  0.99734545,  0.2829785 , -1.50629471, -0.57860025])

# %%
X_train
# Out:
# array([[50.  , 26.41,  0.  , ...,  1.  ,  0.  ,  0.  ],
#        [21.  , 26.4 ,  1.  , ...,  0.  ,  0.  ,  1.  ],
#        [25.  , 26.22,  0.  , ...,  0.  ,  0.  ,  0.  ],
#        ...,
#        [51.  , 34.96,  2.  , ...,  0.  ,  0.  ,  0.  ],
#        [40.  , 22.22,  2.  , ...,  0.  ,  1.  ,  0.  ],
#        [57.  , 27.94,  1.  , ...,  0.  ,  1.  ,  0.  ]])

# %%
pd.DataFrame(X_train).describe()
# Out:
#                 0           1           2           3           4           5  \
# count  936.000000  936.000000  936.000000  936.000000  936.000000  936.000000
# mean    38.822650   30.682185    1.104701    0.511752    0.206197    0.238248
# std     14.029097    6.087997    1.222664    0.500129    0.404790    0.426239
# min     18.000000   15.960000    0.000000    0.000000    0.000000    0.000000
# 25%     26.000000   26.272500    0.000000    0.000000    0.000000    0.000000
# 50%     38.000000   30.495000    1.000000    1.000000    0.000000    0.000000
# 75%     51.000000   34.717500    2.000000    1.000000    0.000000    0.000000
# max     64.000000   53.130000    5.000000    1.000000    1.000000    1.000000
#
#                 6           7
# count  936.000000  936.000000
# mean     0.264957    0.256410
# std      0.441546    0.436884
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train_std = scaler.transform(X_train)
pd.DataFrame(X_train_std).describe()
# Out:
#                   0             1             2             3             4  \
# count  9.360000e+02  9.360000e+02  9.360000e+02  9.360000e+02  9.360000e+02
# mean  -9.014631e-17  3.054122e-15 -1.869795e-16 -1.119712e-16  1.775645e-16
# std    1.000535e+00  1.000535e+00  1.000535e+00  1.000535e+00  1.000535e+00
# min   -1.485041e+00 -2.419524e+00 -9.040023e-01 -1.023787e+00 -5.096643e-01
# 25%   -9.144925e-01 -7.247116e-01 -9.040023e-01 -1.023787e+00 -5.096643e-01
# 50%   -5.867016e-02 -3.076297e-02 -8.567913e-02  9.767656e-01 -5.096643e-01
# 75%    8.684707e-01  6.631857e-01  7.326440e-01  9.767656e-01 -5.096643e-01
# max    1.795612e+00  3.689196e+00  3.187613e+00  9.767656e-01  1.962076e+00
#
#                   5             6             7
# count  9.360000e+02  9.360000e+02  9.360000e+02
# mean   1.560955e-16  1.518254e-17  2.436323e-16
# std    1.000535e+00  1.000535e+00  1.000535e+00
# min   -5.592522e-01 -6.003875e-01 -5.872202e-01
# 25%   -5.592522e-01 -6.003875e-01 -5.872202e-01
# 50%   -5.592522e-01 -6.003875e-01 -5.872202e-01
# 75%   -5.592522e-01  1.665591e+00  1.702939e+00
# max    1.788102e+00  1.665591e+00  1.702939e+00

# %%
pd.DataFrame(X_train_std)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0
# 25  -0.587220
# 26  -0.587220
# 27  -0.587220
# 28  -0.587220
# 29  -0.587220
# ..        ...
# 906 -0.587220
# 907 -0.587220
# 908 -0.587220
# 909 -0.587220
# 910  1.702939
# 911 -0.587220
# 912 -0.587220
# 913  1.702939
# 914  1.702939
# 915 -0.587220
# 916 -0.587220
# 917 -0.587220
# 918 -0.587220
# 919 -0.587220
# 920 -0.587220
# 921 -0.587220
# 922 -0.587220
# 923 -0.587220
# 924 -0.587220
# 925 -0.587220
# 926 -0.587220
# 927  1.702939
# 928 -0.587220
# 929 -0.587220
# 930 -0.587220
# 931  1.702939
# 932 -0.587220
# 933 -0.587220
# 934 -0.587220
# 935 -0.587220
#
# [936 rows x 8 columns]

# %%
X_test_std = scaler.transform(X_test)

# %%
from sklearn import linear_model

# %%
est = linear_model.LinearRegression()
est.fit(X_train_std, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
est.coef_
# Out:
# array([  251.68186515,   322.38910684,   344.9642553 ,  -282.79634661,
#        24059.39047692,  -304.09009765,  -939.34209691,  -868.18855866])

# %%
pd.DataFrame({"feature": features, 
            "weight": est.coef_})
# Out:
#             feature        weight
# 0               age    251.681865
# 1               bmi    322.389107
# 2          children    344.964255
# 3       gender_male   -282.796347
# 4        smoker_yes  24059.390477
# 5  region_northwest   -304.090098
# 6  region_southeast   -939.342097
# 7  region_southwest   -868.188559

# %%
y_train_pred = est.predict(X_train_std)

# %%
res = pd.DataFrame({"actual": y_train, "predicted": y_train_pred})
res["error"] = res.actual - res.predicted
res
# Out:
#           actual     predicted         error
# 0     8827.20990   9472.264706   -645.054806
# 1     2597.77900   2233.928867    363.850133
# 2     2721.32080   3423.054245   -701.733445
# 3    10702.64240  10718.882756    -16.240356
# 4     9391.34600  13789.363595  -4398.017595
# 5    17878.90068   8575.538050   9303.362630
# 6    34838.87300  29070.391813   5768.481187
# 7    28950.46920  37270.077567  -8319.608367
# 8    11482.63485   3474.235997   8008.398853
# 9     1704.70015    650.591339   1054.108811
# 10   12430.95335  14185.866667  -1754.913317
# 11   16115.30450  27363.128132 -11247.823632
# 12    5662.22500  11312.876891  -5650.651891
# 13   11394.06555  14228.036144  -2833.970594
# 14    5003.85300   5860.421131   -856.568131
# 15    1964.78000    280.938585   1683.841415
# 16   13415.03810  10808.451521   2606.586579
# 17    1967.02270   2715.930292   -748.907592
# 18   18963.17192   8152.412366  10810.759554
# 19    8125.78450  11951.073117  -3825.288617
# 20    3385.39915   4784.460516  -1399.061366
# 21    3577.99900   6452.088555  -2874.089555
# 22    4889.03680   6727.848706  -1838.811906
# 23   26125.67477  24987.189253   1138.485517
# 24    1241.56500  -1024.963571   2266.528571
# 25    1708.00140   1416.265468    291.735932
# 26   12495.29085  14828.750829  -2333.459979
# 27   36898.73308  27972.439480   8926.293600
# 28   18767.73770  29799.955047 -11032.217347
# 29    1674.63230   4162.704309  -2488.072009
# ..           ...           ...           ...
# 906  44423.80300  37271.409105   7152.393895
# 907   3490.54910   6041.080065  -2550.530965
# 908  11512.40500  13309.714705  -1797.309705
# 909  11833.78230   9959.767626   1874.014674
# 910  34472.84100  28451.655710   6021.185290
# 911   3238.43570   8240.683440  -5002.247740
# 912  12913.99240  12080.186194    833.806206
# 913   2494.02200   4438.054794  -1944.032794
# 914  14988.43200  12860.505691   2127.926309
# 915  45710.20785  38662.918606   7047.289244
# 916  44260.74990  37107.694188   7153.055712
# 917   7633.72060   9866.449521  -2232.728921
# 918  23288.92840   4193.321139  19095.607261
# 919   5257.50795   5301.689171    -44.181221
# 920   9620.33070  10854.682622  -1234.351922
# 921  22462.04375  32545.406730 -10083.362980
# 922  62592.87309  32911.430830  29681.442260
# 923   2055.32490   4262.790391  -2207.465491
# 924   2464.61880   2998.410290   -533.791490
# 925   3044.21330   3147.899075   -103.685775
# 926   3062.50825   5374.731035  -2312.222785
# 927   6082.40500   9250.518070  -3168.113070
# 928  20745.98910  30267.957810  -9521.968710
# 929   2730.10785   6555.035644  -3824.927794
# 930   2438.05520  10114.233494  -7676.178294
# 931  12146.97100  12227.733773    -80.762773
# 932   4564.19145   5658.150817  -1093.959367
# 933  44641.19740  37816.578866   6824.618534
# 934  19444.26580  30001.499032 -10557.233232
# 935  11554.22360  11437.005352    117.218248
#
# [936 rows x 3 columns]

# %%
mse_training = np.mean(res.error ** 2)
mse_training
# Out:
# 36476790.764106855

# %%
from sklearn import metrics

# %%
mse_training = metrics.mean_squared_error(y_train, y_train_pred)
mse_training
# Out:
# 36476790.76410686

# %%
mse_testing = metrics.mean_squared_error(y_test, 
                                        est.predict(X_test_std))
mse_testing
# Out:
# 36761456.35201328

# %%
mse_training/mse_testing
# Out:
# 0.9922564115746518

# %%
np.var(y_test)
# Out:
# 141716672.9185044

# %%
r2 = 1 - mse_testing/np.var(y_test)
r2
# Out:
# 0.7405989316927211

# %%
y_test_pred = est.predict(X_test_std)
metrics.r2_score(y_test, y_test_pred)
# Out:
# 0.740598931692721

# %%
metrics.r2_score(y_train, y_train_pred)
# Out:
# 0.7545557492633161

# %%
from sklearn import pipeline

# %%
target = "charges"
y = df[target].values
X = pd.get_dummies(df.drop(columns=[target]), drop_first=True).values

X_train, X_test, y_train, y_test = \
    model_selection.train_test_split(X, y, test_size = 0.3
                                    , random_state = 1)

pipe = pipeline.Pipeline([
    ("scaler", StandardScaler()),
    ("est", linear_model.LinearRegression())
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

train_mse = metrics.mean_squared_error(y_train, y_train_pred)
test_mse = metrics.mean_squared_error(y_test, y_test_pred)

train_r2 = metrics.r2_score(y_train, y_train_pred)
test_r2 = metrics.r2_score(y_test, y_test_pred)

print("MSE: train: %f, test: %f" % (train_mse, test_mse))
print("R2: train: %f, test: %f" % (train_r2, test_r2))
# Out:
# MSE: train: 36476790.764107, test: 36761456.352013
# R2: train: 0.754556, test: 0.740599

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(y);

# %%
plt.boxplot(np.log(y));

# %%
target = "charges"
y = np.log(df[target].values)
X = pd.get_dummies(df.drop(columns=[target]), drop_first=True).values

X_train, X_test, y_train, y_test = \
    model_selection.train_test_split(X, y, test_size = 0.3
                                    , random_state = 1)

pipe = pipeline.Pipeline([
    ("scaler", StandardScaler()),
    ("est", linear_model.LinearRegression())
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

train_mse = metrics.mean_squared_error(y_train, y_train_pred)
test_mse = metrics.mean_squared_error(y_test, y_test_pred)

train_r2 = metrics.r2_score(y_train, y_train_pred)
test_r2 = metrics.r2_score(y_test, y_test_pred)

print("MSE: train: %f, test: %f" % (train_mse, test_mse))
print("R2: train: %f, test: %f" % (train_r2, test_r2))
# Out:
# MSE: train: 0.204072, test: 0.178811
# R2: train: 0.758910, test: 0.787430

# %%
target = "charges"
y = np.log(df[target].values)
df["high_bmi"] = np.where(df.bmi > 30, 1, 0)
X = pd.get_dummies(df.drop(columns=[target]), drop_first=True).values

X_train, X_test, y_train, y_test = \
    model_selection.train_test_split(X, y, test_size = 0.3
                                    , random_state = 1)

pipe = pipeline.Pipeline([
    ("scaler", StandardScaler()),
    ("est", linear_model.LinearRegression())
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

train_mse = metrics.mean_squared_error(y_train, y_train_pred)
test_mse = metrics.mean_squared_error(y_test, y_test_pred)

train_r2 = metrics.r2_score(y_train, y_train_pred)
test_r2 = metrics.r2_score(y_test, y_test_pred)

print("MSE: train: %f, test: %f" % (train_mse, test_mse))
print("R2: train: %f, test: %f" % (train_r2, test_r2))
# Out:
# MSE: train: 0.203391, test: 0.178078
# R2: train: 0.759715, test: 0.788302

# %%
target = "charges"
y = np.log(df[target].values)
df["senior"] = np.where(df.age>60, 1, 0)
df["high_bmi"] = np.where(df.bmi > 30, 1, 0)
X = pd.get_dummies(df.drop(columns=[target]), drop_first=True).values

X_train, X_test, y_train, y_test = \
    model_selection.train_test_split(X, y, test_size = 0.3
                                    , random_state = 1)

pipe = pipeline.Pipeline([
    ("scaler", StandardScaler()),
    ("est", linear_model.LinearRegression())
])

pipe.fit(X_train, y_train)
y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

train_mse = metrics.mean_squared_error(y_train, y_train_pred)
test_mse = metrics.mean_squared_error(y_test, y_test_pred)

train_r2 = metrics.r2_score(y_train, y_train_pred)
test_r2 = metrics.r2_score(y_test, y_test_pred)

print("MSE: train: %f, test: %f" % (train_mse, test_mse))
print("R2: train: %f, test: %f" % (train_r2, test_r2))
# Out:
# MSE: train: 0.202395, test: 0.176601
# R2: train: 0.760891, test: 0.790057
