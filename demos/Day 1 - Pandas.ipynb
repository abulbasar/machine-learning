# %%
import pandas as pd

# %%
df = pd.read_csv("/data/insurance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Common operations
#
# 1. info and data types of each column
# 2. Shape ... number of records and columns
# 3. Slice ...
# 4. Filter
# 6. Group .. aggregation
# 7. Sorting
# 8. Join ... merge two datasets (concatenation, join by key)
# 9. Pivoting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
numeric_features = [col for col, dtype in df.dtypes.items() if dtype != "O"] 
categorical_features = [col for col, dtype in df.dtypes.items() if dtype == "O"] 

numeric_features, categorical_features
# Out:
# (['age', 'bmi', 'children', 'charges'], ['gender', 'smoker', 'region'])

# %%
df.shape # rows, columns
# Out:
# (1338, 7)

# %%
df.shape[0]
# Out:
# 1338

# %%
type(df.shape)
# Out:
# tuple

# %%
df.iloc[:3, :]
# Out:
#    age  gender    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.iloc[-3:, :]
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.iloc[-3:, -3:]
# Out:
#      smoker     region     charges
# 1335     no  southeast   1629.8335
# 1336     no  southwest   2007.9450
# 1337    yes  northwest  29141.3603

# %%
df.loc[1335:, ["smoker", "region","charges"]]
# Out:
#      smoker     region     charges
# 1335     no  southeast   1629.8335
# 1336     no  southwest   2007.9450
# 1337    yes  northwest  29141.3603

# %%
df.loc[:, ["smoker", "region","charges"]].iloc[-3:, :]
# Out:
#      smoker     region     charges
# 1335     no  southeast   1629.8335
# 1336     no  southwest   2007.9450
# 1337    yes  northwest  29141.3603

# %%
df.iloc[10:15, :]
# Out:
#     age  gender    bmi  children smoker     region     charges
# 10   25    male  26.22         0     no  northeast   2721.3208
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 12   23    male  34.40         0     no  southwest   1826.8430
# 13   56  female  39.82         0     no  southeast  11090.7178
# 14   27    male  42.13         0    yes  southeast  39611.7577

# %%
df.loc[10:15, :]
# Out:
#     age  gender    bmi  children smoker     region     charges
# 10   25    male  26.22         0     no  northeast   2721.3208
# 11   62  female  26.29         0    yes  southeast  27808.7251
# 12   23    male  34.40         0     no  southwest   1826.8430
# 13   56  female  39.82         0     no  southeast  11090.7178
# 14   27    male  42.13         0    yes  southeast  39611.7577
# 15   19    male  24.60         1     no  southwest   1837.2370

# %%
df[["smoker", "region","charges"]]
# Out:
#      smoker     region      charges
# 0       yes  southwest  16884.92400
# 1        no  southeast   1725.55230
# 2        no  southeast   4449.46200
# 3        no  northwest  21984.47061
# 4        no  northwest   3866.85520
# 5        no  southeast   3756.62160
# 6        no  southeast   8240.58960
# 7        no  northwest   7281.50560
# 8        no  northeast   6406.41070
# 9        no  northwest  28923.13692
# 10       no  northeast   2721.32080
# 11      yes  southeast  27808.72510
# 12       no  southwest   1826.84300
# 13       no  southeast  11090.71780
# 14      yes  southeast  39611.75770
# 15       no  southwest   1837.23700
# 16       no  northeast  10797.33620
# 17       no  northeast   2395.17155
# 18       no  southwest  10602.38500
# 19      yes  southwest  36837.46700
# 20       no  northeast  13228.84695
# 21       no  southwest   4149.73600
# 22       no  southeast   1137.01100
# 23      yes  northeast  37701.87680
# 24       no  northwest   6203.90175
# ...

# %%
df[df.gender == "male"]
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 2      28   male  33.000         3     no  southeast   4449.46200
# 3      33   male  22.705         0     no  northwest  21984.47061
# 4      32   male  28.880         0     no  northwest   3866.85520
# 8      37   male  29.830         2     no  northeast   6406.41070
# 10     25   male  26.220         0     no  northeast   2721.32080
# 12     23   male  34.400         0     no  southwest   1826.84300
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 15     19   male  24.600         1     no  southwest   1837.23700
# 17     23   male  23.845         0     no  northeast   2395.17155
# 18     56   male  40.300         0     no  southwest  10602.38500
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 22     18   male  34.100         0     no  southeast   1137.01100
# ...

# %%
df.query("gender == 'male'")
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 2      28   male  33.000         3     no  southeast   4449.46200
# 3      33   male  22.705         0     no  northwest  21984.47061
# 4      32   male  28.880         0     no  northwest   3866.85520
# 8      37   male  29.830         2     no  northeast   6406.41070
# 10     25   male  26.220         0     no  northeast   2721.32080
# 12     23   male  34.400         0     no  southwest   1826.84300
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 15     19   male  24.600         1     no  southwest   1837.23700
# 17     23   male  23.845         0     no  northeast   2395.17155
# 18     56   male  40.300         0     no  southwest  10602.38500
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 22     18   male  34.100         0     no  southeast   1137.01100
# ...

# %%
df.groupby("gender").age.mean()
# Out:
# gender
# female    39.503021
# male      38.917160
# Name: age, dtype: float64

# %%
df.groupby("gender").age.agg(["mean", "count"])
# Out:
#              mean  count
# gender
# female  39.503021    662
# male    38.917160    676

# %%
df.groupby("gender").agg({"age": ["mean", "count"], "bmi": ["mean", "count"]})
# Out:
#               age              bmi
#              mean count       mean count
# gender
# female  39.503021   662  30.377749   662
# male    38.917160   676  30.943129   676

# %%
df.sort_values("bmi")
# Out:
#       age  gender     bmi  children smoker     region      charges
# 172    18    male  15.960         0     no  northeast   1694.79640
# 428    21  female  16.815         1     no  northeast   3167.45585
# 1226   38    male  16.815         2     no  northeast   6640.54485
# 412    26  female  17.195         2    yes  northeast  14455.64405
# 1286   28  female  17.290         0     no  northeast   3732.62510
# 1029   37  female  17.290         2     no  northeast   6877.98010
# 250    18    male  17.290         2    yes  northeast  12829.45510
# 28     23    male  17.385         1     no  northwest   2775.19215
# 680    21  female  17.400         1     no  southwest   2585.26900
# 410    19    male  17.480         0     no  northwest   1621.34020
# 821    26    male  17.670         0     no  northwest   2680.94930
# 128    32  female  17.765         2    yes  northwest  32734.18630
# 232    19  female  17.800         0     no  southwest   1727.78500
# ...

# %%
df.sort_values("bmi", ascending = False)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 847    23    male  50.380         1     no  southeast   2438.05520
# 116    58    male  49.060         0     no  southeast  11381.32540
# 286    46  female  48.070         2     no  northeast   9432.92530
# 1088   52    male  47.740         1     no  southeast   9748.91060
# 860    37  female  47.600         2    yes  southwest  46113.51100
# 401    47    male  47.520         1     no  southeast   8083.91980
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 438    52  female  46.750         5     no  southeast  12592.53450
# 547    54  female  46.700         2     no  southwest  11538.42100
# 454    32    male  46.530         2     no  southeast   4686.38870
# 930    26    male  46.530         1     no  southeast   2927.06470
# ...

# %%
import numpy as np

# %%
np.percentile(df.bmi, [90])
# Out:
# array([38.6195])

# %%
df.bmi.mean(), df.bmi.median()
# Out:
# (30.663396860986538, 30.4)

# %%
a = np.array([3, 9, 1, 2, 10, 23, 1])
a
# Out:
# array([ 3,  9,  1,  2, 10, 23,  1])

# %%
sorted(a)
# Out:
# [1, 1, 2, 3, 9, 10, 23]

# %%
np.mean(a), np.median(a)
# Out:
# (7.0, 3.0)

# %%
a = np.array([3, 9, 1, 2, 10, 23, 1,1000])
np.mean(a), np.median(a) # median is robust statistic
# Out:
# (131.125, 6.0)

# %%
pd.merge?
