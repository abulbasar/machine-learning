# %%
import pandas as pd

# %%
movies = pd.read_csv("/data/movielens/movies.csv")

# %%
movies
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
gf = movies[movies.title.str.contains("Godfather")]
gf
# Out:
#       movieId                            title                        genres
# 695       858            Godfather, The (1972)                   Crime|Drama
# 977      1221   Godfather: Part II, The (1974)                   Crime|Drama
# 1585     2023  Godfather: Part III, The (1990)  Crime|Drama|Mystery|Thriller
# 5470     8607          Tokyo Godfathers (2003)     Adventure|Animation|Drama

# %%
movies[movies.movieId.isin(gf.movieId.values)]
# Out:
#       movieId                            title                        genres
# 695       858            Godfather, The (1972)                   Crime|Drama
# 977      1221   Godfather: Part II, The (1974)                   Crime|Drama
# 1585     2023  Godfather: Part III, The (1990)  Crime|Drama|Mystery|Thriller
# 5470     8607          Tokyo Godfathers (2003)     Adventure|Animation|Drama

# %%
gf.movieId.values[0]
# Out:
# 858

# %%
gf.loc[695, :]
# Out:
# movieId                      858
# title      Godfather, The (1972)
# genres               Crime|Drama
# Name: 695, dtype: object

# %%
movies.query("movieId == 858")
# Out:
#      movieId                  title       genres
# 695      858  Godfather, The (1972)  Crime|Drama

# %%
movies.loc[695, :]
# Out:
# movieId                      858
# title      Godfather, The (1972)
# genres               Crime|Drama
# Name: 695, dtype: object

# %%
movies.iloc[690:700, :]
# Out:
#      movieId                                              title  \
# 690      849                            Escape from L.A. (1996)
# 691      850                             Cyclo (Xich lo) (1995)
# 692      851                                    Basquiat (1996)
# 693      852                                     Tin Cup (1996)
# 694      854  Ballad of Narayama, The (Narayama Bushiko) (1958)
# 695      858                              Godfather, The (1972)
# 696      861  Supercop (Police Story 3: Supercop) (Jing cha ...
# 697      864                                   Wife, The (1995)
# 698      865                                 Small Faces (1996)
# 699      866                                       Bound (1996)
#
#                                genres
# 690  Action|Adventure|Sci-Fi|Thriller
# 691                       Crime|Drama
# 692                             Drama
# 693              Comedy|Drama|Romance
# 694                             Drama
# ...

# %%
ratings = pd.read_csv("/data/movielens/ratings.csv")

# %%
rating_for_858 = ratings[ratings.movieId == 858]
rating_for_858
# Out:
#        userId  movieId  rating   timestamp
# 180         4      858     5.0   949779022
# 370         5      858     2.5  1163373651
# 602         8      858     5.0  1154400181
# 1140       15      858     5.0   997938703
# 2730       17      858     5.0  1127469000
# 3324       19      858     5.0   855191478
# 3564       20      858     2.0  1238729822
# 3678       21      858     4.0   853850728
# 3823       22      858     4.0  1131662354
# 4093       23      858     5.0  1148670263
# 4810       26      858     4.0  1360088089
# 5188       30      858     5.0   945113250
# 6071       31      858     4.5  1273720163
# 6350       34      858     4.0   973746463
# 6674       38      858     4.5  1389722583
# 7403       48      858     4.0  1367729182
# 8814       57      858     5.0   907765902
# 9087       59      858     5.0  1144756296
# 9154       60      858     5.0  1125829174
# 9535       65      858     5.0   945149894
# 9574       66      858     5.0   974600461
# ...

# %%
rating_for_858.shape[0]
# Out:
# 200

# %%
rating_for_858.rating.mean()
# Out:
# 4.4875

# %%
top10 = (ratings
 .groupby("movieId")
 .rating
 .agg(["count", "mean"])
 .query("count >= 100")
 .sort_values("mean", ascending = False)
 .iloc[:10, :]
)
top10
# Out:
#          count      mean
# movieId
# 858        200  4.487500
# 318        311  4.487138
# 1221       135  4.385185
# 50         201  4.370647
# 527        244  4.303279
# 1193       144  4.256944
# 608        224  4.256696
# 296        324  4.256173
# 2858       220  4.236364
# 58559      121  4.235537

# %%
top10.merge(movies, right_on= "movieId", left_index=True)[["title", "movieId", "mean"]]
# Out:
#                                        title  movieId      mean
# 695                    Godfather, The (1972)      858  4.487500
# 284         Shawshank Redemption, The (1994)      318  4.487138
# 977           Godfather: Part II, The (1974)     1221  4.385185
# 48                Usual Suspects, The (1995)       50  4.370647
# 472                  Schindler's List (1993)      527  4.303279
# 951   One Flew Over the Cuckoo's Nest (1975)     1193  4.256944
# 535                             Fargo (1996)      608  4.256696
# 266                      Pulp Fiction (1994)      296  4.256173
# 2288                  American Beauty (1999)     2858  4.236364
# 6916                 Dark Knight, The (2008)    58559  4.235537
