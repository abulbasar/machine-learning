# %%
import pandas as pd

# %%
df = pd.read_csv("/data/insurance.csv")
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.head(10)
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
# !head -n 10 /data/insurance.csv
# Out:
# age,gender,bmi,children,smoker,region,charges
# 19,female,27.9,0,yes,southwest,16884.924
# 18,male,33.77,1,no,southeast,1725.5523
# 28,male,33,3,no,southeast,4449.462
# 33,male,22.705,0,no,northwest,21984.47061
# 32,male,28.88,0,no,northwest,3866.8552
# 31,female,25.74,0,no,southeast,3756.6216
# 46,female,33.44,1,no,southeast,8240.5896
# 37,female,27.74,3,no,northwest,7281.5056
# 37,male,29.83,2,no,northeast,6406.4107

# %%
df.tail()
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.tail(10)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
len(df)
# Out:
# 1338

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
dict(df.dtypes)
# Out:
# {'age': dtype('int64'),
#  'gender': dtype('O'),
#  'bmi': dtype('float64'),
#  'children': dtype('int64'),
#  'smoker': dtype('O'),
#  'region': dtype('O'),
#  'charges': dtype('float64')}

# %%
df.sample(10)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 394    46  female  32.300         2     no  northeast   9411.00500
# 578    52    male  30.200         1     no  southwest   9724.53000
# 1105   54  female  31.240         0     no  southeast  10338.93160
# 286    46  female  48.070         2     no  northeast   9432.92530
# 1044   55    male  35.245         1     no  northeast  11394.06555
# 408    38    male  21.120         3     no  southeast   6652.52880
# 1067   39    male  42.655         0     no  northeast   5757.41345
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1068   63    male  21.660         1     no  northwest  14349.85440
# 598    43    male  32.600         2     no  southwest   7441.50100

# %%
df.iloc[100:105, :]
# Out:
#      age  gender     bmi  children smoker     region     charges
# 100   41  female  31.600         0     no  southwest   6186.1270
# 101   30    male  25.460         0     no  northeast   3645.0894
# 102   18  female  30.115         0     no  northeast  21344.8467
# 103   61  female  29.920         3    yes  southeast  30942.1918
# 104   34  female  27.500         1     no  southwest   5003.8530

# %%
x = [3, 7, 0, 10, 3, 10]
x[:]
# Out:
# [3, 7, 0, 10, 3, 10]

# %%
df.iloc[100:105, :3]
# Out:
#      age  gender     bmi
# 100   41  female  31.600
# 101   30    male  25.460
# 102   18  female  30.115
# 103   61  female  29.920
# 104   34  female  27.500

# %%
df.iloc[100:105, [0, 4, 3, 2]]
# Out:
#      age smoker  children     bmi
# 100   41     no         0  31.600
# 101   30     no         0  25.460
# 102   18     no         0  30.115
# 103   61    yes         3  29.920
# 104   34     no         1  27.500

# %%
df.loc[100:105, ["age", "smoker"]]
# Out:
#      age smoker
# 100   41     no
# 101   30     no
# 102   18     no
# 103   61    yes
# 104   34     no
# 105   20    yes

# %%
df["age"]
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
df.age
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
df[((df.gender == "male") & (df.age<20))]
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 15     19   male  24.600         1     no  southwest   1837.23700
# 22     18   male  34.100         0     no  southeast   1137.01100
# 35     19   male  20.425         0     no  northwest   1625.43375
# 57     18   male  31.680         2    yes  southeast  34303.16720
# 121    18   male  23.750         0     no  northeast   1705.62450
# 133    19   male  25.555         0     no  northwest   1632.56445
# 136    19   male  34.100         0     no  southwest   1261.44200
# 149    19   male  28.400         1     no  southwest   1842.51900
# 157    18   male  25.175         0    yes  northeast  15518.18025
# 172    18   male  15.960         0     no  northeast   1694.79640
# 194    18   male  34.430         0     no  southeast   1137.46970
# 195    19   male  30.590         0     no  northwest   1639.56310
# ...

# %%
df.query("gender == 'male' and age<20")
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 15     19   male  24.600         1     no  southwest   1837.23700
# 22     18   male  34.100         0     no  southeast   1137.01100
# 35     19   male  20.425         0     no  northwest   1625.43375
# 57     18   male  31.680         2    yes  southeast  34303.16720
# 121    18   male  23.750         0     no  northeast   1705.62450
# 133    19   male  25.555         0     no  northwest   1632.56445
# 136    19   male  34.100         0     no  southwest   1261.44200
# 149    19   male  28.400         1     no  southwest   1842.51900
# 157    18   male  25.175         0    yes  northeast  15518.18025
# 172    18   male  15.960         0     no  northeast   1694.79640
# 194    18   male  34.430         0     no  southeast   1137.46970
# 195    19   male  30.590         0     no  northwest   1639.56310
# ...

# %%
pd.options.display.max_rows = 1000

# %%
df["age"]
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.gender.value_counts()
# Out:
# male      676
# female    662
# Name: gender, dtype: int64

# %%
df.gender.value_counts()/len(df)
# Out:
# male      0.505232
# female    0.494768
# Name: gender, dtype: float64

# %%
df.groupby("gender").age.mean()
# Out:
# gender
# female    39.503021
# male      38.917160
# Name: age, dtype: float64

# %%
df.groupby("gender")["age"].mean()
# Out:
# gender
# female    39.503021
# male      38.917160
# Name: age, dtype: float64

# %%
df.groupby("gender")["age"].agg(["mean","median"])
# Out:
#              mean  median
# gender
# female  39.503021      40
# male    38.917160      39

# %%
def my_mean(x):
    return sum(x)/len(x)

# %%
df.groupby("gender")["age"].agg(["mean", "median", my_mean])
# Out:
#              mean  median    my_mean
# gender
# female  39.503021      40  39.503021
# male    38.917160      39  38.917160

# %%
import numpy as np

# %%
df.groupby("gender")["age"].agg(["median", my_mean, np.mean])
# Out:
#         median    my_mean       mean
# gender
# female      40  39.503021  39.503021
# male        39  38.917160  38.917160

# %%
df.groupby(["smoker", "gender"]).agg({"age": ["mean", "std"]
                                , "bmi": ["mean", "std"]})
# Out:
#                      age                   bmi
#                     mean        std       mean       std
# smoker gender
# no     female  39.691042  14.025538  30.539525  5.901781
#        male    39.061896  14.150768  30.770580  6.192641
# yes    female  38.608696  14.217419  29.608261  6.663802
#        male    38.446541  13.751247  31.504182  5.952028

# %%
df["bmi_div_age"] = 10 * df["bmi"]/df["age"]
df
# Out:
#       age  gender     bmi  children smoker     region      charges  \
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
#       bmi_div_age
# 0       14.684211
# 1       18.761111
# 2       11.785714
# 3        6.880303
# 4        9.025000
# ...           ...
# 1333     6.194000
# ...

# %%
df.drop(columns="bmi_div_age", inplace=True)

# %%
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.sort_values("charges", ascending=False)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# ...   ...     ...     ...       ...    ...        ...          ...
# 22     18    male  34.100         0     no  southeast   1137.01100
# 663    18    male  33.660         0     no  southeast   1136.39940
# 1244   18    male  33.330         0     no  southeast   1135.94070
# 808    18    male  30.140         0     no  southeast   1131.50660
# 940    18    male  23.210         0     no  southeast   1121.87390
#
# [1338 rows x 7 columns]

# %%
df.iloc[-df.index, :]
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1337   61  female  29.070         0    yes  northwest  29141.36030
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1334   18  female  31.920         0     no  northeast   2205.98080
# ...   ...     ...     ...       ...    ...        ...          ...
# 5      31  female  25.740         0     no  southeast   3756.62160
# 4      32    male  28.880         0     no  northwest   3866.85520
# 3      33    male  22.705         0     no  northwest  21984.47061
# 2      28    male  33.000         3     no  southeast   4449.46200
# 1      18    male  33.770         1     no  southeast   1725.55230
#
# [1338 rows x 7 columns]

# %%
df1 = df.query("gender == 'male' and age>63")
df1.sort_index()
# Out:
#       age gender     bmi  children smoker     region      charges
# 62     64   male  24.700         1     no  northwest  30166.61817
# 335    64   male  34.500         0     no  southwest  13822.80300
# 398    64   male  25.600         2     no  southwest  14988.43200
# 418    64   male  39.160         1     no  southeast  14418.28040
# 420    64   male  33.880         0    yes  southeast  46889.26120
# 534    64   male  40.480         0     no  southeast  13831.11520
# 635    64   male  38.190         0     no  northeast  14410.93210
# 752    64   male  37.905         0     no  northwest  14210.53595
# 1051   64   male  26.410         0     no  northeast  14394.55790
# 1241   64   male  36.960         2    yes  southeast  49577.66240
# 1265   64   male  23.760         0    yes  southeast  26926.51440

# %%
df1 = df.groupby("smoker").age.median()

# %%
df1
# Out:
# smoker
# no     40
# yes    38
# Name: age, dtype: int64

# %%
df1.sort_index(ascending = False)
# Out:
# charges
# 63770.42801    54
# 62592.87309    45
# 60021.39897    52
# 58571.07448    31
# 55135.40209    33
#                ..
# 1137.01100     18
# 1136.39940     18
# 1135.94070     18
# 1131.50660     18
# 1121.87390     18
# Name: age, Length: 1337, dtype: int64

# %%
df = pd.read_csv("/data/startups.csv",header=None)
df.sort_values(1)
# Out:
#             0               1                2           3          4
# 3   153441.51       101145.55        407934.54     Florida  191050.39
# 34   55493.95       103057.49        214634.81     Florida   96778.92
# 24   67532.53       105751.03        304768.73     Florida  108733.99
# 10  123334.88       108679.17        304981.62  California  149759.96
# 11  101913.08       110594.11        229160.95     Florida  146121.95
# 21   76253.86        113867.3        298664.47  California  118474.03
# 19   91749.16       114175.79        294919.57     Florida   124266.9
# 31   61994.48       115641.28         91131.24     Florida   99937.59
# 47    1315.46       115816.21        297114.46     Florida   49490.75
# 50        NaN        116983.8         45173.06  California    14681.4
# 41   28754.33       118546.05        172795.67  California   78239.91
# 4   144372.41       118671.85        383199.62    New York  182901.99
# ...

# %%
df.sort_index(ascending = False)
# Out:
#             0               1                2           3          4
# 50        NaN        116983.8         45173.06  California    14681.4
# 49     542.05        51743.15              NaN    New York   35673.41
# 48        NaN       135426.92              NaN  California   42559.73
# 47    1315.46       115816.21        297114.46     Florida   49490.75
# 46    1000.23       124153.04          1903.93    New York   64926.08
# 45   22177.74       154806.14         28334.72  California   65200.33
# 44   15505.73        127382.3         35534.17    New York   69758.98
# 43   23640.93        96189.63        148001.11  California   71498.49
# 42   27892.92        84710.77        164470.71     Florida   77798.83
# 41   28754.33       118546.05        172795.67  California   78239.91
# 40   38558.51        82982.09         174999.3  California   81005.76
# 39   20229.59        65947.93         185265.1    New York   81229.06
# ...
