# %%
import pandas as pd

# %%
df = pd.read_csv("/data/insurance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.head(10)
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail()
# Out:
#       age  gender    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.sample(10)
# Out:
#       age  gender     bmi  children smoker     region      charges
# 796    30    male  44.220         2     no  southeast   4266.16580
# 1072   21    male  31.255         0     no  northwest   1909.52745
# 514    39    male  28.300         1    yes  southwest  21082.16000
# 1089   56    male  22.100         0     no  southwest  10577.08700
# 1151   58  female  36.480         0     no  northwest  12235.83920
# 179    41  female  33.155         3     no  northeast   8538.28845
# 693    24    male  23.655         0     no  northwest   2352.96845
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 50     18  female  35.625         0     no  northeast   2211.13075
# 234    39    male  24.510         2     no  northwest   6710.19190

# %%
df.iloc[20:25,:3]
# Out:
#     age  gender     bmi
# 20   60  female  36.005
# 21   30  female  32.400
# 22   18    male  34.100
# 23   34  female  31.920
# 24   37    male  28.025

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# gender      1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df[(df.gender == "male") & (df.bmi>33)]
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 12     23   male  34.400         0     no  southwest   1826.84300
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 18     56   male  40.300         0     no  southwest  10602.38500
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 22     18   male  34.100         0     no  southeast   1137.01100
# 29     31   male  36.300         2    yes  southwest  38711.00000
# 30     22   male  35.600         0    yes  southwest  35585.57600
# 34     28   male  36.400         1    yes  southwest  51194.55914
# 38     35   male  36.670         1    yes  northeast  39774.27630
# 39     60   male  39.900         0    yes  southwest  48173.36100
# 44     38   male  37.050         1     no  northeast   6079.67150
# 45     55   male  37.300         0     no  southwest  20630.28351
# ...

# %%
df.query("gender =='male' and bmi>33")
# Out:
#       age gender     bmi  children smoker     region      charges
# 1      18   male  33.770         1     no  southeast   1725.55230
# 12     23   male  34.400         0     no  southwest   1826.84300
# 14     27   male  42.130         0    yes  southeast  39611.75770
# 18     56   male  40.300         0     no  southwest  10602.38500
# 19     30   male  35.300         0    yes  southwest  36837.46700
# 22     18   male  34.100         0     no  southeast   1137.01100
# 29     31   male  36.300         2    yes  southwest  38711.00000
# 30     22   male  35.600         0    yes  southwest  35585.57600
# 34     28   male  36.400         1    yes  southwest  51194.55914
# 38     35   male  36.670         1    yes  northeast  39774.27630
# 39     60   male  39.900         0    yes  southwest  48173.36100
# 44     38   male  37.050         1     no  northeast   6079.67150
# 45     55   male  37.300         0     no  southwest  20630.28351
# ...

# %%
df.sort_values(["age", "charges"], ascending=[True, False])
# Out:
#       age  gender     bmi  children smoker     region       charges
# 803    18  female  42.240         0    yes  southeast  38792.685600
# 759    18    male  38.170         0    yes  southeast  36307.798300
# 161    18  female  36.850         0    yes  southeast  36149.483500
# 623    18    male  33.535         0    yes  northeast  34617.840650
# 57     18    male  31.680         2    yes  southeast  34303.167200
# 911    18    male  31.730         0    yes  northeast  33732.686700
# 102    18  female  30.115         0     no  northeast  21344.846700
# 1204   18  female  27.280         3    yes  southeast  18223.451200
# 1170   18    male  27.360         1    yes  northeast  17178.682400
# 157    18    male  25.175         0    yes  northeast  15518.180250
# 1282   18  female  21.660         0    yes  northeast  14283.459400
# 354    18  female  38.280         0     no  southeast  14133.037750
# 1033   18    male  21.565         0    yes  northeast  13747.872350
# ...

# %%
df.groupby("gender").charges.mean()
# Out:
# gender
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
df.groupby("gender")["charges","age"].mean()
# Out:
#              charges        age
# gender
# female  12569.578844  39.503021
# male    13956.751178  38.917160

# %%
df.groupby("gender")["charges","age"].agg(["min","max","mean"])
# Out:
#           charges                            age
#               min          max          mean min max       mean
# gender
# female  1607.5101  63770.42801  12569.578844  18  64  39.503021
# male    1121.8739  62592.87309  13956.751178  18  64  38.917160

# %%
df.groupby("gender").agg({"charges": ["min","max"], "age": "mean"})
# Out:
#           charges                     age
#               min          max       mean
# gender
# female  1607.5101  63770.42801  39.503021
# male    1121.8739  62592.87309  38.917160

# %%
df.groupby(["region", "gender"]).agg({"charges": ["min","max"], "age": "mean"})
# Out:
#                      charges                     age
#                          min          max       mean
# region    gender
# northeast female  2196.47320  58571.07448  39.639752
#           male    1694.79640  48549.17835  38.901840
# northwest female  2117.33885  55135.40209  39.591463
#           male    1621.34020  60021.39897  38.795031
# southeast female  1607.51010  63770.42801  39.108571
#           male    1121.87390  62592.87309  38.783069
# southwest female  1727.78500  48824.45000  39.703704
#           male    1241.56500  52590.82939  39.208589
