# %%
import pandas as pd

# %%
df = pd.read_json("https://raw.githubusercontent.com/abulbasar/data/master/sms.json")

# %%
df.head()
# Out:
#                                                    body  spam
# 0     Go until jurong point, crazy.. Available only ...     0
# 1                         Ok lar... Joking wif u oni...     0
# 10    I'm gonna be home soon and i don't want to tal...     0
# 100   Please don't text me anymore. I have nothing e...     0
# 1000          Aight will do, thanks again for comin out     0

# %%
df.to_csv("/data/sms.csv", index=False)

# %%
df.shape
# Out:
# (5574, 2)

# %%
df.spam.value_counts()
# Out:
# 0    4827
# 1     747
# Name: spam, dtype: int64

# %%
df[df.spam == 1]
# Out:
#                                                    body  spam
# 1002  Please call our customer service representativ...     1
# 1007  Panasonic & BluetoothHdset FREE. Nokia FREE. M...     1
# 1017  FREE for 1st week! No1 Nokia tone 4 ur mob eve...     1
# 1022  Guess what! Somebody you know secretly fancies...     1
# 1045  We know someone who you know that fancies you....     1
# 1048  1000's flirting NOW! Txt GIRL or BLOKE & ur NA...     1
# 1050  18 days to Euro2004 kickoff! U will be kept in...     1
# 1060  EASTENDERS TV Quiz. What FLOWER does DOT compa...     1
# 1064  We have new local dates in your area - Lots of...     1
# 1069  Someone U know has asked our dating service 2 ...     1
# 1072  URGENT! We are trying to contact U. Todays dra...     1
# 1073  Dear U've been invited to XCHAT. This is our f...     1
# 1089  You are awarded a SiPix Digital Camera! call 0...     1
# 1091  WIN URGENT! Your mobile number has been awarde...     1
# ...
