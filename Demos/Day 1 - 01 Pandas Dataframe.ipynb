# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/data/insurance.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.values
# Out:
# array([[19, 'female', 27.9, ..., 'yes', 'southwest', 16884.924],
#        [18, 'male', 33.77, ..., 'no', 'southeast', 1725.5523],
#        [28, 'male', 33.0, ..., 'no', 'southeast', 4449.462],
#        ...,
#        [18, 'female', 36.85, ..., 'no', 'southeast', 1629.8335],
#        [21, 'female', 25.8, ..., 'no', 'southwest', 2007.945],
#        [61, 'female', 29.07, ..., 'yes', 'northwest', 29141.3603]],
#       dtype=object)

# %% [markdown]
# # Operations with dataframe
#
# - find the number of rows and columns
# - find column types
# - filter based on condition
# - grouping or aggregation
# - access data based on row or column indexes or name
# - sort
# - join/merge two dataframe

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
# age         1338 non-null int64
# sex         1338 non-null object
# bmi         1338 non-null float64
# children    1338 non-null int64
# smoker      1338 non-null object
# region      1338 non-null object
# charges     1338 non-null float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.2+ KB

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 268    45    male  30.200         1     no  southwest   7441.05300
# 462    62  female  38.095         2     no  northeast  15230.32405
# 550    63    male  30.800         0     no  southwest  13390.55900
# 529    18    male  25.460         0     no  northeast   1708.00140
# 928    62  female  39.160         0     no  southeast  13470.80440
# 1025   21  female  34.600         0     no  southwest   2020.17700
# 650    49  female  42.680         2     no  southeast   9800.88820
# 108    29    male  27.940         0     no  southeast   2867.11960
# 205    28  female  28.880         1     no  northeast   4337.73520
# 452    24    male  23.400         0     no  southwest   1969.61400

# %%
df[df.sex == "male"].head()
# Out:
#    age   sex     bmi  children smoker     region      charges
# 1   18  male  33.770         1     no  southeast   1725.55230
# 2   28  male  33.000         3     no  southeast   4449.46200
# 3   33  male  22.705         0     no  northwest  21984.47061
# 4   32  male  28.880         0     no  northwest   3866.85520
# 8   37  male  29.830         2     no  northeast   6406.41070

# %%
df.query("sex == 'male'").head()
# Out:
#    age   sex     bmi  children smoker     region      charges
# 1   18  male  33.770         1     no  southeast   1725.55230
# 2   28  male  33.000         3     no  southeast   4449.46200
# 3   33  male  22.705         0     no  northwest  21984.47061
# 4   32  male  28.880         0     no  northwest   3866.85520
# 8   37  male  29.830         2     no  northeast   6406.41070

# %%
df.groupby("sex").charges.agg([np.mean, len])
# Out:
#                 mean    len
# sex
# female  12569.578844  662.0
# male    13956.751178  676.0

# %%
df.groupby("sex").charges.agg([np.mean, len]).reset_index()
# Out:
#       sex          mean    len
# 0  female  12569.578844  662.0
# 1    male  13956.751178  676.0

# %%
df[["age", "region"]]
# Out:
#       age     region
# 0      19  southwest
# 1      18  southeast
# 2      28  southeast
# 3      33  northwest
# 4      32  northwest
# 5      31  southeast
# 6      46  southeast
# 7      37  northwest
# 8      37  northeast
# 9      60  northwest
# 10     25  northeast
# 11     62  southeast
# 12     23  southwest
# 13     56  southeast
# 14     27  southeast
# 15     19  southwest
# 16     52  northeast
# 17     23  northeast
# 18     56  southwest
# 19     30  southwest
# 20     60  northeast
# 21     30  southwest
# 22     18  southeast
# 23     34  northeast
# 24     37  northwest
# 25     59  southeast
# 26     63  northeast
# 27     55  northwest
# 28     23  northwest
# 29     31  southwest
# ...   ...        ...
# 1308   25  southwest
# 1309   41  southwest
# 1310   42  northwest
# 1311   33  northwest
# 1312   34  southwest
# 1313   19  southwest
# 1314   30  northwest
# 1315   18  northeast
# 1316   19  southwest
# 1317   18  southeast
# 1318   35  northeast
# ...

# %%
df.iloc[[1, 2, 4, 5, 6]]
# Out:
#    age     sex    bmi  children smoker     region    charges
# 1   18    male  33.77         1     no  southeast  1725.5523
# 2   28    male  33.00         3     no  southeast  4449.4620
# 4   32    male  28.88         0     no  northwest  3866.8552
# 5   31  female  25.74         0     no  southeast  3756.6216
# 6   46  female  33.44         1     no  southeast  8240.5896

# %%
df.iloc[[1, 2, 4, 5, 6], [4, 5]]
# Out:
#   smoker     region
# 1     no  southeast
# 2     no  southeast
# 4     no  northwest
# 5     no  southeast
# 6     no  southeast

# %%
df.loc[[1, 2, 4, 5, 6], ["smoker", "region"]]
# Out:
#   smoker     region
# 1     no  southeast
# 2     no  southeast
# 4     no  northwest
# 5     no  southeast
# 6     no  southeast

# %%
df.sort_values("bmi")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 172    18    male  15.960         0     no  northeast   1694.79640
# 428    21  female  16.815         1     no  northeast   3167.45585
# 1226   38    male  16.815         2     no  northeast   6640.54485
# 412    26  female  17.195         2    yes  northeast  14455.64405
# 1286   28  female  17.290         0     no  northeast   3732.62510
# 1029   37  female  17.290         2     no  northeast   6877.98010
# 250    18    male  17.290         2    yes  northeast  12829.45510
# 28     23    male  17.385         1     no  northwest   2775.19215
# 680    21  female  17.400         1     no  southwest   2585.26900
# 410    19    male  17.480         0     no  northwest   1621.34020
# 821    26    male  17.670         0     no  northwest   2680.94930
# 128    32  female  17.765         2    yes  northwest  32734.18630
# 232    19  female  17.800         0     no  southwest   1727.78500
# ...

# %%
df.sort_values("bmi", ascending = False)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1047   22    male  52.580         1    yes  southeast  44501.39820
# 847    23    male  50.380         1     no  southeast   2438.05520
# 116    58    male  49.060         0     no  southeast  11381.32540
# 286    46  female  48.070         2     no  northeast   9432.92530
# 1088   52    male  47.740         1     no  southeast   9748.91060
# 860    37  female  47.600         2    yes  southwest  46113.51100
# 401    47    male  47.520         1     no  southeast   8083.91980
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 438    52  female  46.750         5     no  southeast  12592.53450
# 547    54  female  46.700         2     no  southwest  11538.42100
# 454    32    male  46.530         2     no  southeast   4686.38870
# 930    26    male  46.530         1     no  southeast   2927.06470
# ...

# %%
pd.merge?

# %% [markdown]
# Exercise: Find 10 movies based on highest average ratings. Each top 10 movies must have got at least 100 ratings.
#
# Steps
# 1. Load movies.csv as movies dataframe
# 2. Load ratings.csv as ratings dataframe
# 3. Find the number of rows in movies and ratings dataframes
# 4. Based on ratings dataframe, find avarage rating and number of ratings for each movie Id
# 5. In the above aggregation filter out all moviesId which have got fewer than 100 ratings
# 6. Marge the above the filetered data with movies dataframe to add a column column to it.
# 7. Sort the data to find top 10 movies based on highest average rating.
