# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import *
import numpy as np
import tensorflow as tf
# Out:
# /Users/abulbasar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df_train = pd.read_csv("/data/MNIST/mnist_train.csv", header = None)
df_test = pd.read_csv("/data/MNIST/mnist_test.csv", header = None)

# %%
df_train.shape
# Out:
# (60000, 785)

# %%
df_test.shape
# Out:
# (10000, 785)

# %%
28 ** 2
# Out:
# 784

# %%
scaler = preprocessing.StandardScaler() 
X_train = scaler.fit_transform(df_train.iloc[:, 1:].values)
X_test = scaler.transform(df_test.iloc[:, 1:].values)
y_train = df_train.iloc[:, 0]
y_test = df_test.iloc[:, 0]
# Out:
# /Users/abulbasar/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
y_train.value_counts().sort_index().plot.bar()

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
fig, _ = plt.subplots(10, 5, figsize=(8, 16))

for i, ax in enumerate(fig.axes):
    ax.imshow(X_train[i].reshape(28, 28), cmap="Greys")
    ax.set_title(y_train[i])
plt.tight_layout()

# %%
lr = linear_model.LogisticRegression(multi_class="multinomial")
lr.fit(X_train, y_train)
lr.score(X_test, y_test)

# %%
import tensorflow as tf
# Out:
# /Users/abulbasar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
a = tf.constant(2.0)
b = tf.constant(3.0)
c = a + b

with tf.Session() as sess:
    print(sess.run(c))
# Out:
# 5.0

# %%
tf.reset_default_graph()

a = tf.placeholder(shape=[], dtype=tf.float32)
b = tf.placeholder(shape=[], dtype=tf.float32)
c = a + b
print("a", a)
print("b", b)
print("c", c)

with tf.Session() as sess:
    print(sess.run(c, feed_dict={a: 2.0, b: 4.0}))
# Out:
# a Tensor("Placeholder:0", shape=(), dtype=float32)
# b Tensor("Placeholder_1:0", shape=(), dtype=float32)
# c Tensor("add:0", shape=(), dtype=float32)
# 6.0

# %%
a = np.random.random([6, 3])
b = np.random.random([3, 2])
c = a.dot(b)
c
# Out:
# array([[0.12741857, 0.46859209],
#        [0.41575879, 0.68720668],
#        [0.25864508, 0.65983017],
#        [0.44120289, 0.92802915],
#        [0.27132926, 1.08437087],
#        [0.47774073, 1.23295193]])

# %%
a = np.array([2, 3, 4])
b = np.array([0, 1, 4])
np.dot(a, b)
# Out:
# 19

# %%
a = np.array([
    [2, 3, 4],
    [4, 0, -1],
    [3, 1, 5],
    [9, -2 ,4]
])#(4,3)

b = np.array(
    [0, 1, 4]
).T #(3,)

np.dot(a, b)#(4,)
# Out:
# array([19, -4, 21, 14])

# %%
a = np.array([
    [2, 3, 4],
    [4, 0, -1],
    [3, 1, 5],
    [9, -2 ,4]
])#(4,3)

b = np.array([
    [0, 1, 4]
]).T #(3, 1)

np.dot(a, b)#(4,)
# Out:
# array([[19],
#        [-4],
#        [21],
#        [14]])

# %%
a = np.array([
    [2, 3, 4],
    [4, 0, -1],
    [3, 1, 5],
    [9, -2 ,4]
])#(4,3)

a * 3
# Out:
# array([[ 6,  9, 12],
#        [12,  0, -3],
#        [ 9,  3, 15],
#        [27, -6, 12]])

# %%
a = np.array([
    [2, 3, 4],
    [4, 0, -1],
    [3, 1, 5],
    [9, -2 ,4]
])#(4,3)

# %%
b = np.identity(4)[:, :-1]
b
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [0., 0., 0.]])

# %%
a * b
# Out:
# array([[ 2.,  0.,  0.],
#        [ 0.,  0., -0.],
#        [ 0.,  0.,  5.],
#        [ 0., -0.,  0.]])

# %%
a = np.array([
    [2, 3, 4],
    [4, 0, -1],
    [3, 1, 5],
    [9, -2 ,4]
])
b = np.identity(4)
np.column_stack([a, b])
# Out:
# array([[ 2.,  3.,  4.,  1.,  0.,  0.,  0.],
#        [ 4.,  0., -1.,  0.,  1.,  0.,  0.],
#        [ 3.,  1.,  5.,  0.,  0.,  1.,  0.],
#        [ 9., -2.,  4.,  0.,  0.,  0.,  1.]])

# %%
a = np.array([
    [2, 3, 4],
    [4, 0, -1],
    [3, 1, 5],
    [9, -2 ,4]
])

b = np.array([1, 2, 3])
c
# Out:
# array([[ 1,  1,  1],
#        [ 3, -2, -4],
#        [ 2, -1,  2],
#        [ 8, -4,  1]])

# %%
(a - b) ** 2
# Out:
# array([[ 1,  1,  1],
#        [ 9,  4, 16],
#        [ 4,  1,  4],
#        [64, 16,  1]])

# %%
np.sum((a - b) ** 2)
# Out:
# 122

# %%
np.sum((a - b) ** 2, axis = 0)
# Out:
# array([78, 22, 22])

# %%
np.sum((a - b) ** 2, axis = 1)
# Out:
# array([ 3, 29,  9, 81])

# %%
np.random.random([4, 5, 6])[0,:,:]
# Out:
# array([[0.60633873, 0.05897996, 0.99071864, 0.11678379, 0.30539206,
#         0.05538447],
#        [0.02049926, 0.94652173, 0.89590926, 0.72748489, 0.1370051 ,
#         0.98543349],
#        [0.70075337, 0.57064883, 0.18504216, 0.71557686, 0.28459601,
#         0.78232412],
#        [0.76470238, 0.59336144, 0.23270803, 0.14020271, 0.0487209 ,
#         0.47977435],
#        [0.71970078, 0.82536905, 0.41979971, 0.1791179 , 0.14319003,
#         0.68450546]])

# %%
df = pd.read_csv("/data/insurance.csv")
#df = df.query("smoker != 'yes'").query("sex == 'male'")
y = np.log(df.charges)
X = pd.get_dummies(df.iloc[:, 0:-1], drop_first=True)
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, 
                                            test_size = 0.3, random_state = 1)

# %%
def find_color(row):
    if not row.smoker =="yes":
        return "blue"
    else:
        if row.children > 0:
            return "green"
        else:
            return "red" 
    
colors = df.apply(find_color, axis = 1)
df.plot.scatter("age", "charges", color = colors)

# %%
est = ensemble.GradientBoostingRegressor()
est.fit(X_train, y_train)
y_test_pred = est.predict(X_test)
metrics.mean_squared_error(y_test, y_test_pred)
# Out:
# 0.11158550095637056

# %%
X_train.shape
# Out:
# (936, 8)

# %%
lr = linear_model.LinearRegression()
lr.fit(X_train, y_train)
y_test_pred = lr.predict(X_test)
metrics.mean_squared_error(y_test, y_test_pred)
# Out:
# 0.18293024762539029

# %%
plt.scatter(y_test, y_test - y_test_pred)
plt.xlabel("y")
plt.ylabel("residual")
plt.title("Residual plot")
# Out:
# Text(0.5,1,'Residual plot')

# %%
import seaborn as sns

# %%
df_tmp = pd.get_dummies(df, drop_first=True)
sns.pairplot(df_tmp, y_vars=["charges"], x_vars=df_tmp.columns)

# %%
X.shape, df_tmp.shape, lr.predict(X).shape
# Out:
# ((1338, 8), (1338, 9), (1338,))

# %%
df_tmp.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
df_tmp['error'] = lr.predict(X) - y
#df_tmp.head()
sns.pairplot(df_tmp, y_vars=["error"], x_vars=df_tmp.columns)

# %%
plt.hist(y_test, bins = 50);

# %%
plt.hist(y_test - y_test_pred, bins = 50);
plt.title("Distribution of the residuals")
# Out:
# Text(0.5,1,'Distribution of the residuals')

# %%
tf.reset_default_graph()
tf.set_random_seed(1)

n_x = X_train.shape[1]
n_y = 1
n_h = 3
learning_rate = 1e-1
max_iter = 5000

X = tf.placeholder(dtype=tf.float32, shape=[None, n_x], name = "X")
y = tf.placeholder(dtype=tf.float32, shape=[None, 1], name = "y")

print("X", X)
print("y", y)

W1 = tf.Variable(initial_value= tf.truncated_normal(shape=[n_x, n_h]))
b1 = tf.Variable(tf.zeros(shape=[n_h]))
print("W1", W1)
print("b1", b1)

Z1 = tf.matmul(X, W1) + b1
print("Z1", Z1)

A1 = tf.nn.relu(Z1)

W2 = tf.Variable(initial_value= tf.truncated_normal(shape=[n_h, n_y]))
b2 = tf.Variable(tf.zeros(shape=[n_y]))
print("W2", W2)
print("b2", b2)

Z2 = tf.matmul(A1, W2) + b2
print("Z2", Z2)

y_pred = Z2

mse = tf.reduce_mean((y - y_pred) ** 2)
print("mse", mse)

optimizer = tf.train.AdamOptimizer(learning_rate).minimize(mse)

scores = []
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for i in range(max_iter):
        mse_, _ = sess.run([mse, optimizer], feed_dict={X: X_train,
                                            y: y_train.reshape(-1, 1)})
        scores.append(mse_)
        if i % (max_iter//25) == 0 or i == max_iter-1:
            print(mse_)
    test_mse_, y_pred_ = sess.run([mse, y_pred], feed_dict={X: X_test,
                                            y: y_test.reshape(-1, 1)})
    print("Test mse", test_mse_)
# Out:
# X Tensor("X:0", shape=(?, 8), dtype=float32)
# y Tensor("y:0", shape=(?, 1), dtype=float32)
# W1 <tf.Variable 'Variable:0' shape=(8, 3) dtype=float32_ref>
# b1 <tf.Variable 'Variable_1:0' shape=(3,) dtype=float32_ref>
# Z1 Tensor("add:0", shape=(?, 3), dtype=float32)
# W2 <tf.Variable 'Variable_2:0' shape=(3, 1) dtype=float32_ref>
# b2 <tf.Variable 'Variable_3:0' shape=(1,) dtype=float32_ref>
# Z2 Tensor("add_1:0", shape=(?, 1), dtype=float32)
# mse Tensor("Mean:0", shape=(), dtype=float32)
# /Users/abulbasar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# 243.51892
# 0.80224377
# 0.35505062
# 0.22598083
# 0.20536706
# 0.20329593
# 0.2028968
# 0.2024163
# 0.20171936
# 0.20365432
# 0.19987886
# 0.38412625
# 0.19099067
# 0.18033311
# 0.16706032
# 0.1569086
# 0.16879725
# 0.15387902
# 0.15350103
# 0.15370674
# 0.15333135
# 0.15473667
# 0.15322483
# ...

# %%
pd.Series(scores).plot()
plt.xlabel("Iteration")
plt.ylabel("MSE")
# Out:
# Text(0,0.5,'MSE')

# %%
metrics.mean_squared_error(y_test, y_pred_.flatten())
# Out:
# 85.59403016591187

# %%
plt.scatter(y_test, y_test-y_pred_.flatten())

# %%
plt.hist(y_test-y_pred_.flatten(), bins = 50);

# %%
scaler = preprocessing.StandardScaler() 
X_train = scaler.fit_transform(df_train.iloc[:, 1:].values)
X_test = scaler.transform(df_test.iloc[:, 1:].values)
y_train = df_train.iloc[:, 0]
y_test = df_test.iloc[:, 0]
# Out:
# /Users/abulbasar/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
import requests
url = "https://raw.githubusercontent.com/abulbasar/machine-learning/master/Utils.py"
exec(requests.get(url).text)

# %%
tf.reset_default_graph()
tf.set_random_seed(1)

n_x = X_train.shape[1]
n_y = 10
n_h = 400
learning_rate = 1e-1
max_iter = 200

X = tf.placeholder(dtype=tf.float32, shape=[None, n_x], name = "X")
y = tf.placeholder(dtype=tf.int32, shape=[None], name = "y")

print("X", X)
print("y", y)

y_oh = tf.one_hot(y, depth=n_y)
print("y_oh", y_oh)

W1 = tf.Variable(initial_value= tf.truncated_normal(shape=[n_x, n_h]))
b1 = tf.Variable(tf.zeros(shape=[n_h]))
print("W1", W1)
print("b1", b1)

Z1 = tf.matmul(X, W1) + b1
print("Z1", Z1)

A1 = tf.nn.relu(Z1)

W2 = tf.Variable(initial_value= tf.truncated_normal(shape=[n_h, n_y]))
b2 = tf.Variable(tf.zeros(shape=[n_y]))
print("W2", W2)
print("b2", b2)

Z2 = tf.matmul(A1, W2) + b2
print("Z2", Z2)

y_pred = tf.argmax(Z2, axis=1, output_type=tf.int32)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z2, labels=y_oh))

accuracy = tf.reduce_mean(tf.cast(tf.equal(y, y_pred), tf.float32))

optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

scores = []
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    batchable = Batchable(X_train, y_train, batch_size=128, seed=1)
    
    for i in range(max_iter):
        X_batch, y_batch = batchable.next()
        cost_, _ = sess.run([cost, optimizer], feed_dict={X: X_train,y: y_train})
        scores.append(cost_)
        if i % (max_iter//25) == 0 or i == max_iter-1:
            train_accuracy_ = sess.run(accuracy, feed_dict={X: X_train,y: y_train})
            test_accuracy_ = sess.run(accuracy, feed_dict={X: X_test,y: y_test})
            print("cost", cost_, " train", train_accuracy_, "test:", test_accuracy_)
    y_pred_, A1_, W1_, W2_ = sess.run([y_pred, A1, W1, W2], feed_dict={X: X_test,y: y_test})
pd.Series(scores).plot()
# Out:
# X Tensor("X:0", shape=(?, 784), dtype=float32)
# y Tensor("y:0", shape=(?,), dtype=int32)
# y_oh Tensor("one_hot:0", shape=(?, 10), dtype=float32)
# W1 <tf.Variable 'Variable:0' shape=(784, 400) dtype=float32_ref>
# b1 <tf.Variable 'Variable_1:0' shape=(400,) dtype=float32_ref>
# Z1 Tensor("add:0", shape=(?, 400), dtype=float32)
# W2 <tf.Variable 'Variable_2:0' shape=(400, 10) dtype=float32_ref>
# b2 <tf.Variable 'Variable_3:0' shape=(10,) dtype=float32_ref>
# Z2 Tensor("add_1:0", shape=(?, 10), dtype=float32)
# cost 474.02524  train 0.66111666 test: 0.6766
# cost 54.962402  train 0.90491664 test: 0.9035
# cost 30.548492  train 0.93451667 test: 0.9279
# cost 17.460188  train 0.95145 test: 0.939
# cost 10.301812  train 0.9637667 test: 0.9495
# cost 6.1654863  train 0.9724 test: 0.9526
# cost 3.8586078  train 0.97858334 test: 0.9554
# cost 2.438192  train 0.9838667 test: 0.9565
# cost 1.528563  train 0.9878 test: 0.9573
# cost 0.96303296  train 0.99111664 test: 0.9579
# ...

# %%
result = pd.DataFrame({"actual": y_test, "pred": y_pred_.flatten()})
result["match"] = result.actual == result.pred 
result.head()
# Out:
#    actual  pred  match
# 0       7     7   True
# 1       2     2   True
# 2       1     1   True
# 3       0     0   True
# 4       4     4   True

# %%
result_agg = result.groupby(["actual", "match"]).count().unstack().reset_index()
result_agg["ratio"] =
# Out:
#       actual  pred
# match        False  True
# 0          0    22   958
# 1          1    16  1119
# 2          2    46   986
# 3          3    38   972
# 4          4    31   951
# 5          5    38   854
# 6          6    29   929
# 7          7    42   986
# 8          8    53   921
# 9          9    54   955

# %%
agg = result.query("match == True")
agg.actual.value_counts()
# Out:
# 1    1119
# 7     986
# 2     986
# 3     972
# 0     958
# 9     955
# 4     951
# 6     929
# 8     921
# 5     854
# Name: actual, dtype: int64

# %%
result.query("match != True").actual.value_counts()
# Out:
# 9    54
# 8    53
# 2    46
# 7    42
# 5    38
# 3    38
# 4    31
# 6    29
# 0    22
# 1    16
# Name: actual, dtype: int64

# %%
fig, _ = plt.subplots(10, 5, figsize=(8, 16))

for i, ax in enumerate(fig.axes):
    ax.imshow(X_test[~result.match][i].reshape(28, 28), cmap="Greys")
    title = ("T:" 
                 + str(y_test.values[~result.match][i]) 
                 + " P:"
                 + str(y_pred_[~result.match][i]))
    ax.set_title(title)
plt.tight_layout()

# %%
60000/32
# Out:
# 1875.0

# %%
plt.imshow(X_test[0].reshape(28, -1), cmap="Greys")

# %%
plt.imshow(A1_[0].reshape(20, -1), cmap="Greys")

# %%
c_filter=y_test == 4

# %%
fig, _ = plt.subplots(10, 2, figsize=(8, 16))

for i in range(10):
    ax1 = fig.axes[2*i]
    ax2 = fig.axes[2*i+1]
    ax1.imshow(X_test[c_filter][i].reshape(28, -1), cmap="Greys")
    ax2.imshow(A1_[c_filter][i].reshape(20, -1), cmap="Greys")

plt.tight_layout()

# %%
W2_.shape
# Out:
# (400, 10)

# %%
fig, _ = plt.subplots(2, 5, figsize = (10, 10))

for i, ax in enumerate(fig.axes):
    ax.imshow(W2_[:, i].reshape(20, 20), cmap="Greys")

plt.tight_layout()
